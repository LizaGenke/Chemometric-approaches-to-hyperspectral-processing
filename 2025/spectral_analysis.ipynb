# %%
# Clone repo (if running in Colab)
# !git clone https://github.com/LizaGenke/Chemometric-approaches-to-hyperspectral-processing.git

# Navigate into the cloned repository
# %cd Chemometric-approaches-to-hyperspectral-processing

# Install dependencies
# !pip install -r requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
# Define the path to your data and result folders in Google Drive
# data_path="data"
# results_dir = "results"
data_path = '/content/drive/MyDrive/Chemometrics_Approaches_for_Hyperspectral_Image_Processing/data'
results_dir = '/content/drive/MyDrive/Chemometrics_Approaches_for_Hyperspectral_Image_Processing_Results'
os.makedirs(results_dir, exist_ok=True)

# %% [markdown]
# # Spectral analysis

# %% [markdown]
# This notebook demonstrates a complete workflow for spectral analysis and calibration modeling.
#
# It covers:
# 1. Loading and visualizing spectral and reference data.
# 2. Unsupervised outlier detection using PCA and Mahalanobis distance.
# 3. Outlier removal based on input and output variables.
# 4. Preprocessing techniques: smoothing, scatter correction (MSC/SNV), and derivatives.
# 5. Automated preprocessing pipeline selection using the nippy library.
# 6. Data partitioning methods: Kennard-Stone, DUPLEX, and SPXY.
# 7. Calibration modeling: Principal Component Regression (PCR) and Partial Least Squares Regression (PLSR).
# 8. Model diagnostics, supervised outlier detection, and performance visualization.
# 9. Deep learning regression using fully connected neural networks.

# %% [markdown]
# ## Loading of the spectral data and references

# %% [markdown]
# As a first step we will load the average spectra of kiwi that we generated in the previous lab. We also load reference values (dry matter and soluble solids content) and select the refernce values that correspond to extracted spectra.

# %%
import numpy as np

kiwi_spectra = np.loadtxt(f"{results_dir}/kiwi_avg_spectra.csv", delimiter=",")
reference_values = np.loadtxt(f"{data_path}/reference.csv", delimiter=",")
wl = np.loadtxt(f"{results_dir}/wavelengths.csv", delimiter=",")
reference_values = reference_values[:180, :] # Select correct refernce values (first 180 rows) that exclude golden kiwi sort
reference_values.shape
# Out:
# (180, 2)

# %% [markdown]
# ## Outliers removal (unsupervised, PCA)

# %% [markdown]
# Due to potential mishaps in our measurements or extraction of spectra per kiwi and various other reasons we may end up having outliers in our dataset. These outliers can cause problems when training chemometrics/machine learning model. Let's explore unsupervised outlier removal that we perform using principal component analysis (PCA):

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

scaler = StandardScaler()
scaled_data = scaler.fit_transform(kiwi_spectra)
 
pca = PCA(random_state=42)
 
# Run PCA on scaled data (since PCA is sensitive to feature scale) and obtain the scores array
T = pca.fit_transform(scaled_data)
 
# Score plot of the first 2 PC
fig = plt.figure(figsize=(8,6))
with plt.style.context(('ggplot')):
    plt.scatter(T[:, 0], T[:, 1], edgecolors='k')
    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.title('Score Plot')
plt.show()

# %% [markdown]
# Let's plot explained variance by each principal component

# %%
explained_var_ratio = pca.explained_variance_ratio_
cumulative_var_ratio = np.cumsum(explained_var_ratio)

plt.figure(figsize=(10, 5))
plt.bar(range(1, len(explained_var_ratio)+1), explained_var_ratio, alpha=0.5, align='center', label='Individual explained variance')
plt.step(range(1, len(cumulative_var_ratio)+1), cumulative_var_ratio, where='mid', label='Cumulative explained variance')
plt.axhline(y=0.95, color='r', linestyle='--', label='95% threshold')
plt.xlabel('Principal Component Index')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance by Principal Components')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

n_components_95 = np.argmax(cumulative_var_ratio >= 0.95) + 1
print(f"Number of components explaining 95% variance: {n_components_95}")
# Out:
# Number of components explaining 95% variance: 4

# %% [markdown]
# We can check how the first components that explain 95% variance can reconstruct the spectra.

# %%
pca_95 = PCA(n_components=n_components_95, random_state=42)
T_95 = pca_95.fit_transform(scaled_data)
reconstructed = pca_95.inverse_transform(T_95)
reconstructed_original_scale = scaler.inverse_transform(reconstructed)

sample_idx = 0  # You can change this index to look at other samples
plt.figure(figsize=(10, 5))
plt.plot(wl, kiwi_spectra[sample_idx], label='Original Signal')
plt.plot(wl, reconstructed_original_scale[sample_idx], label=f'Reconstructed Signal ({n_components_95} PCs)')
plt.title('Original vs. Reconstructed Spectra (of the first sample)')
plt.xlabel('Wavelength')
plt.ylabel('Absorbance')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# It's a hard task to analyze every spectra across all wavelengths. By computing principal components we can identify where most of variance in our data is and focus on a few first components. After simplifying our data to first let's say 4 components, we can detect outliers by computing distance of each point to the rest. The straightforward way is to compute Euclidean distance, but:
#   - It assumes variables are uncorrelated, which can be misleading when there's correlation between axes (e.g. tilted ellipsoids in PCA score plots).
#   - Redundant or correlated variables can distort distance measures, unintentionally amplifying their influence.
#   - It is sensitive to outliers, which skew mean and standard deviation—making it hard to identify those same outliers.
#
# **Solution: Mahalanobis Distance**
#   - Accounts for the **covariance structure** of the data, giving less weight to directions with high variance (i.e., redundancy).
#   - Can be calculated robustly using **Minimum Covariance Determinant (MCD)** from `sklearn.covariance`.
#   - When applied to PCA-transformed data, it highlights observations that deviate from the multivariate distribution.

# %%
from sklearn.covariance import MinCovDet
 
# fit a Minimum Covariance Determinant (MCD) robust estimator to data 
robust_cov = MinCovDet(random_state=42).fit(T[:,:n_components_95])
 
# Get the Mahalanobis distance
mahalanobis = robust_cov.mahalanobis(T[:,:n_components_95])

# %%
# Plot histogram
plt.hist(mahalanobis, bins=30, edgecolor='black') 
plt.title("Distribution of Values")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.gca().yaxis.set_major_locator(mtick.MaxNLocator(integer=True))
plt.grid(True)
plt.show()

# %%
colors = [plt.cm.jet(float(i)/max(mahalanobis)) for i in mahalanobis]
fig = plt.figure(figsize=(8,6))
with plt.style.context(('ggplot')):
    plt.scatter(T[:, 0], T[:, 1], c=colors, edgecolors='k', s=60)
    plt.xlabel('PC1')
    plt.ylabel('PC2')
    plt.xlim((-40, 40))
    plt.ylim((-40, 40))
    plt.title('Output variable')
plt.show()

# %% [markdown]
# Here we can see that there are a few outliers (in reddish and yellow colors) that seem to be outliers. Using statistical methods we can single them out

# %%
from scipy.stats import chi2

threshold = chi2.ppf(0.99, df=n_components_95)
outliers = mahalanobis > threshold
outlier_indices_input = np.where(outliers)[0]

print("Outlier indices:", outlier_indices_input)
# Out:
# Outlier indices: [ 22  45 142]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(T[:, 0], T[:, 1], c='gray', label='Inliers')
plt.scatter(T[outliers, 0], T[outliers, 1], c='red', label='Outliers', edgecolors='k')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Outlier Detection using Robust Mahalanobis Distance (PCA space)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Outlier removal from multiple references

# %% [markdown]
# Let's repeat the same exercise for our output variables. Since we only have two target variables it does not make sense to compute PCA, since it's a dimension-reduction technique. Let's compute mahalanobis distance based on robust covariance matrix of the output variables.

# %%
robust_cov = MinCovDet(random_state=42).fit(reference_values)

mahalanobis = robust_cov.mahalanobis(reference_values)

colors = [plt.cm.jet(float(i)/max(mahalanobis)) for i in mahalanobis]
fig = plt.figure(figsize=(8,6))
with plt.style.context(('ggplot')):
    plt.scatter(reference_values[:, 0], reference_values[:, 1], c=colors, edgecolors='k', s=60)
    plt.xlabel('Dry matter')
    plt.ylabel('Soluble solids')
    plt.title('Output variable')
plt.show()

# %%
# Plot histogram
plt.hist(mahalanobis, bins=30, edgecolor='black')  
plt.title("Distribution of Values")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.gca().yaxis.set_major_locator(mtick.MaxNLocator(integer=True))
plt.grid(True)
plt.show()

# %%
threshold = chi2.ppf(0.99, df=2)
outliers = mahalanobis > threshold
outlier_indices_output = np.where(outliers)[0]

print("Outlier indices (based on output variables):", outlier_indices_output)
# Out:
# Outlier indices (based on output variables): [ 35  71  77 100 135 150 154 155 159]

# %%
plt.figure(figsize=(6, 5))
plt.scatter(reference_values[:, 0], reference_values[:, 1], c='gray', label='Inliers')
plt.scatter(reference_values[outliers, 0], reference_values[outliers, 1], c='red', edgecolors='k', label='Outliers')
plt.xlabel('Dry matter')
plt.ylabel('Soluble solids')
plt.title('Outlier Detection in Output Variable Space')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Outlier removal from single reference value

# %% [markdown]
# Using the mean ± 3 standard deviations (3σ rule) is a common and simple method based on the assumption that the data is approximately normally distributed. In a normal distribution about 99.7% of the data falls within ±3 standard deviations from the mean.
#
# Values beyond this range are considered statistically rare and often indicative of outliers.

# %%
# Let's say we choose Dry Matter as our target output variable
reference = reference_values[:,0]

# Compute mean and standard deviation
mean = np.mean(reference)
std = np.std(reference)

# Define bounds
lower_bound = mean - 3 * std
upper_bound = mean + 3 * std

plt.figure(figsize=(8, 5))
plt.hist(reference, bins=30, alpha=0.7, color='skyblue', edgecolor='black')
plt.axvline(mean, color='green', linestyle='--', linewidth=2, label='Mean')
plt.axvline(lower_bound, color='red', linestyle='--', linewidth=2)
plt.axvline(upper_bound, color='red', linestyle='--', linewidth=2)
plt.title('Dry matter value distribution with ±3σ bounds')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.gca().yaxis.set_major_locator(mtick.MaxNLocator(integer=True))
plt.tight_layout()
plt.show()


outlier_indices_single_reference = np.where((reference < lower_bound) | (reference > upper_bound))[0]
print("Outlier indices:", outlier_indices_single_reference)
# Out:
# Outlier indices: []

# %%
# Combine unique outlier indices from both sources
combined_outliers = np.union1d(outlier_indices_input, outlier_indices_output)

# Remove those rows from input and output data
X_clean = np.delete(kiwi_spectra, combined_outliers, axis=0)
Y_clean = np.delete(reference, combined_outliers, axis=0)

print(f"Removed {len(combined_outliers)} outliers. Cleaned data shape:")
print("X_clean:", X_clean.shape)
print("Y_clean:", Y_clean.shape)
# Out:
# Removed 12 outliers. Cleaned data shape:
# X_clean: (168, 224)
# Y_clean: (168,)

# %% [markdown]
# ## Pre-processing of data

# %% [markdown]
# ### Smoothing

# %% [markdown]
# Smoothing is applied to reduce noisiness of spectra. The Savitzky–Golay filter is a commonly used smoothing method that fits a low-degree polynomial to a sliding window of data points using least squares. It preserves important features like peak shape and height better than moving average filters.
#
# **Parameters**:
# - `window_length`: number of points in the smoothing window (must be odd)
# - `polyorder`: degree of the fitted polynomial

# %%
from scipy.signal import savgol_filter
 
X_example = X_clean[0, :]

w = 13
p = 2
X_smooth_1 = savgol_filter(X_example, w, polyorder = p, deriv=0)

# %%
plt.figure(figsize=(9,6))
interval = np.arange(0,224,1)
plt.plot(wl[interval], X_example[interval], 'b', label = 'No smoothing')
plt.plot(wl[interval], X_smooth_1[interval], 'r', label = f'Smoothing: w/p = {w/p}')
plt.xlabel("Wavelength (nm)")
plt.ylabel("Reflectance")
plt.legend()
plt.show()

# %% [markdown]
# ## Scatter correction

# %% [markdown]
# Two common methods to reduce light-scattering effects in spectra:
#
# 1. **Multiplicative Scatter Correction (MSC)**
# - Corrects each spectrum by *regressing* against a reference spectrum, often the dataset mean.
# - Removes both additive (baseline offset) and multiplicative (slope) distortions.
# - Reference spectrum must be chosen or estimated.
#
# 2. **Standard Normal Variate (SNV)**
# - Normalizes each spectrum individually without needing a reference.
# - Centers to zero mean and scales to unit variance.
# - Simple and effective for both additive and multiplicative scatter.
#
# ---
#
# - Use **MSC** if a reliable reference spectrum is available (e.g., repeated blank or ideal sample).
# - Use **SNV** when reference isn't available or to preprocess each sample individually.
# - Both help improve calibration models by removing unwanted variability due to sample morphology or measurement conditions.

# %%
def snv(input_data):
    # Define a new array and populate it with the corrected data  
    output_data = np.zeros_like(input_data)
    for i in range(input_data.shape[0]):
 
        # Apply correction
        output_data[i,:] = (input_data[i,:] - np.mean(input_data[i,:])) / np.std(input_data[i,:])
 
    return output_data

# %%
def msc(input_data, reference=None):
    ''' Perform Multiplicative scatter correction'''
 
    # mean centre correction
    for i in range(input_data.shape[0]):
        input_data[i,:] -= input_data[i,:].mean()
 
    # Get the reference spectrum. If not given, estimate it from the mean    
    if reference is None:    
        # Calculate mean
        ref = np.mean(input_data, axis=0)
    else:
        ref = reference
 
    # Define a new array and populate it with the corrected data    
    data_msc = np.zeros_like(input_data)
    for i in range(input_data.shape[0]):
        # Run regression
        fit = np.polyfit(ref, input_data[i,:], 1, full=True)
        # Apply correction
        data_msc[i,:] = (input_data[i,:] - fit[0][1]) / fit[0][0] 
 
    return (data_msc, ref)

# %%
import matplotlib.pyplot as plt
 
Xmsc = msc(X_clean.copy())[0] # Take the first element of the output tuple
Xsnv = snv(X_clean.copy())
 
## Plot spectra
plt.figure(figsize=(8,9))
with plt.style.context(('ggplot')):
    ax1 = plt.subplot(311)
    plt.plot(wl, X_clean.T)
    plt.title('Original data')
 
    ax2 = plt.subplot(312)
    plt.plot(wl, Xmsc.T)
    plt.ylabel('Absorbance spectra')
    plt.title('MSC')
 
    ax2 = plt.subplot(313)
    plt.plot(wl, Xsnv.T)
    plt.xlabel('Wavelength (nm)')
    plt.title('SNV')
    plt.show()

# %% [markdown]
# ## Derivative

# %% [markdown]
# Derivatives of spectra help enhance features like peaks and reduce baseline effects. The **Savitzky–Golay filter** fits a local polynomial to each spectrum and computes its derivatives analytically.
#
# - **First derivative**: highlights slopes and inflection points (e.g. rate of change)
# - **Second derivative**: emphasizes peak curvature and separates overlapping peaks
#
# This is useful for improving model performance in spectroscopy, especially when baseline shift or scatter affects raw spectra.
#
# We apply Savitzky–Golay using `scipy.signal.savgol_filter`.

# %%
# Derivatives
X_cal_1st = savgol_filter(Xsnv, window_length=11, polyorder=2, deriv=1, axis=1)
X_cal_2nd = savgol_filter(Xsnv, window_length=11, polyorder=2, deriv=2, axis=1)

# Plot one sample's raw and derivative spectra
sample_idx = 0

plt.figure(figsize=(10, 6))
plt.plot(wl, Xsnv[sample_idx], label='Original', color='black')
plt.plot(wl, X_cal_1st[sample_idx], label='1st Derivative', color='blue')
plt.plot(wl, X_cal_2nd[sample_idx], label='2nd Derivative', color='red')
plt.xlabel("Wavelength (nm)")
plt.ylabel("Reflectance / Derivative")
plt.title(f"Spectral Derivatives - Sample {sample_idx}")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Data partition

# %% [markdown]
# When training a calibration model it's very important to split our dataset to properly evaluate performance. There are various ways of doing so that are often applied to hyperspectral data (apart from random split via `train_test_split`).

# %% [markdown]
# ### Kennard-Stone partition

# %% [markdown]
# The Kennard–Stone (KS) algorithm is a deterministic method for selecting a representative calibration set from a dataset. It ensures that selected samples are evenly spread across the input (X) space.
#
# How it works:
# 1. Compute pairwise distances between all samples in X.
# 2. Select the two samples that are farthest apart.
# 3. Iteratively add the sample that is most distant from the already selected set.
# 4. Continue until the desired number of samples is selected.
#
# *Note:* KS uses only X (predictors) for selection — not Y (targets). For target-aware splitting, see SPXY algorithm below.

# %%
import kennard_stone as ks
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import cross_validate

X_cal_ks, X_test_ks, y_cal_ks, y_test_ks = ks.train_test_split(X_clean, Y_clean, test_size = 0.2)
# Out:
# /home/liza/miniforge3/envs/hyperspectral311/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2025-11-10 14:10:46,677 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# /home/liza/miniforge3/envs/hyperspectral311/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2025-11-10 14:10:46,679 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# /home/liza/miniforge3/envs/hyperspectral311/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
def plot_split_cal_test(X_cal, X_test, y_cal, y_test):
    _, axs = plt.subplots(2,1,figsize=(8,10))
    _, bins, _ = axs[0].hist(y_cal, bins = 20, alpha=0.75, label="Calibration set")
    axs[0].hist(y_test, bins = bins, alpha=0.75, label="Test set")
    axs[0].legend()
    axs[0].set_xlabel("Dry matter content") 
    axs[0].set_ylabel("Number of samples")
    axs[0].yaxis.set_major_locator(mtick.MaxNLocator(integer=True))

    train_legend =  np.repeat("_Calibration", X_cal.shape[0])
    train_legend[0] = "Calibration set"
    test_legend =  np.repeat("_Test set", X_test.shape[0])
    test_legend[0] = "Test set"

    axs[1].plot(wl, X_cal.T, 'b', alpha=0.5, label = train_legend)
    axs[1].plot(wl, X_test.T, 'g', alpha=0.5, label = test_legend)
    axs[1].legend()
    axs[1].set_xlabel("Wavelength (nm)")
    axs[1].set_ylabel("Kiwi spectra reflectance")
    plt.tight_layout()
    plt.show()

# %%
plot_split_cal_test(X_cal_ks, X_test_ks, y_cal_ks, y_test_ks)

# %% [markdown]
# ### Duplex partition

# %% [markdown]
# The DUPLEX algorithm is a deterministic method for splitting a dataset into two representative sets (e.g., training and testing). It ensures both subsets cover the input space well — better than random splits, especially for small datasets.
#
# How it works:
# 1. Compute pairwise distances between all samples.
# 2. Select the most distant pair → assign one to training, one to testing.
# 3. Alternately add the sample most distant from the current training/test set.
# 4. Repeat until all samples are assigned.

# %%
# ref https://github.com/yuerongz/DUPLEX-data-split-function

import numpy as np
import scipy.spatial.distance as dist
from torch.utils.data import TensorDataset

def np_apply_along_axis(func1d, arr, axis):
  assert arr.ndim == 2
  assert axis in [0, 1]
  if axis == 0:
    result = np.empty(arr.shape[1])
    for i in range(len(result)):
      result[i] = func1d(arr[:, i])
  else:
    result = np.empty(arr.shape[0])
    for i in range(len(result)):
      result[i] = func1d(arr[i, :])
  return result

def allocating_items(dist_m, train_idxs, test_idxs, remaining_idxs, i):
    # 1 samples to Train
    r_of_remains = np.argmax(np_apply_along_axis(np.min, dist_m[:, train_idxs[:i + 2]][remaining_idxs[remaining_idxs != -1]], axis=1))
    r = remaining_idxs[remaining_idxs != -1][int(r_of_remains)]
    train_idxs[i + 2] = r
    remaining_idxs[r] = -1

    # 1 samples to Test
    r_of_remains = np.argmax(np_apply_along_axis(np.min, dist_m[:, test_idxs[:i + 2]][remaining_idxs[remaining_idxs != -1]], axis=1))
    r = remaining_idxs[remaining_idxs != -1][int(r_of_remains)]
    test_idxs[i + 2] = r
    remaining_idxs[r] = -1
    return train_idxs, test_idxs, remaining_idxs

def duplex_data_split(all_data, train_test_ratio):
    """
    Apply DUPLEX split for the provided object.
    all_data = torch.utils.data.TensorDataset, contains tuple(inputs, outputs), where:
        inputs = torch.tensor, size = (batch, sequence_len=192, input_dim=15)
        outputs = torch.tensor, size = (batch, 1, output_dim=1)
        originally prepared for LSTM network training tasks.
    Output: TensorDataset_train, TensorDataset_test
    """
    assert train_test_ratio >= 1, "Duplex split: train-test ratio needs to be no less than one!"

    inputs, outputs = all_data[:]
    train_set_size = round(inputs.size(0) * train_test_ratio / (train_test_ratio + 1))
    test_set_size = int(inputs.size(0) - train_set_size)
    train_idxs = -np.ones(train_set_size, dtype=int)
    test_idxs = -np.ones(test_set_size, dtype=int)

    # process the inputs(3D) and outputs(3D) from the TensorDataset into 2-D matrices
    # inputs: took only the Q and SeaLev sequences, calculate the max() and min() for both sequences,
    #           use them as inputs indicators to avoid massive calculation efforts
    inputs = np.reshape(inputs.numpy()[:, :, [0, -1]], (inputs.size(0), inputs.size(1) * 2))     # (batch, 192, 15)
    inputs = np.array([[max(curr[:1]), min(curr[:1]), max(curr[0:]), min(curr[0:])] for curr in inputs])
    outputs = np.reshape(outputs.numpy(), (outputs.size(0), 1))   # (batch, 1, 1)
    # arrange inputs and outputs into one matrix by join columns
    flattened_all_data = np.concatenate((inputs, outputs), axis=1)   # format=np.ndarray()

    # allocate the first two data sets to training set
    dist_m = dist.cdist(flattened_all_data, flattened_all_data, 'sqeuclidean')
    remaining_idxs = np.arange(dist_m.shape[0])
    r1, r2 = np.argwhere(dist_m == dist_m.max())[0]
    dist_m[r1, :] = 0
    dist_m[r2, :] = 0  # remove distances along deleting item rows
    train_idxs[[0, 1]] = [r1, r2]
    remaining_idxs[[r1, r2]] = -1
    # allocate the first two data sets to testing set
    dist_m2 = dist_m[:, [r1, r2]].copy()
    dist_m[:, r1] = 0
    dist_m[:, r2] = 0
    r1, r2 = np.argwhere(dist_m == dist_m.max())[0]
    test_idxs[[0, 1]] = [r1, r2]
    remaining_idxs[[r1, r2]] = -1
    dist_m[:, train_idxs[:2]] = dist_m2
    dist_m[dist_m == 0] = dist_m.max()

    # while loop, fill test set
    for i in range(test_set_size-2):
        train_idxs, test_idxs, remaining_idxs = allocating_items(dist_m, train_idxs, test_idxs, remaining_idxs, i)

    # put the rest of the data into train set
    if len(remaining_idxs) > 0:
        train_idxs[test_set_size:] = remaining_idxs[remaining_idxs != -1]

    assert np.min(train_idxs) > -1, "Duplex: train set size not matching expectation!"
    assert np.min(test_idxs) > -1, "Duplex: test set size not matching expectation!"

    train_data = TensorDataset(all_data[train_idxs][0], all_data[train_idxs][1])
    test_data = TensorDataset(all_data[test_idxs][0], all_data[test_idxs][1])
    return train_data, test_data

# %%
import torch

# Original 2D data
X_clean_tensor = torch.tensor(X_clean, dtype=torch.float32)  

# Add a singleton dimension in the middle
X_clean_tensor = X_clean_tensor.unsqueeze(1)  # shape: (180, 1, 224)

y_clean_tensor = torch.tensor(Y_clean, dtype=torch.float32)

# Add a singleton dimension in the middle
y_clean_tensor = y_clean_tensor.unsqueeze(1)

# Create TensorDataset
from torch.utils.data import TensorDataset
dataset = TensorDataset(X_clean_tensor, y_clean_tensor)

train_data, test_data = duplex_data_split(dataset, 4)

# %%
X_train_tensor, y_train_tensor = train_data[:]
X_test_tensor, y_test_tensor = test_data[:]
X_cal_duplex = X_train_tensor.squeeze(1).numpy()
X_test_duplex = X_test_tensor.squeeze(1).numpy()
y_cal_duplex = y_train_tensor.numpy().flatten()
y_test_duplex = y_test_tensor.numpy().flatten()

plot_split_cal_test(X_cal_duplex, X_test_duplex, y_cal_duplex, y_test_duplex)

# %% [markdown]
# ### SPXY algorithm

# %% [markdown]
# SPXY is an enhanced variant of the Kennard–Stone (KS) method, designed for splitting datasets into calibration (train) and validation/test sets. While KS uses only the independent variables (X-space) to choose representative samples, SPXY uses both the predictors and the target variable (Y-space) to guide the selection.

# %%
# ref https://hxhc.github.io/post/kennardstone-spxy/
from scipy.spatial.distance import cdist

def max_min_distance_split(distance, train_size):
    """sample set split method based on maximun minimun distance, which is the core of Kennard Stone
    method
    Parameters
    ----------
    distance : distance matrix
        semi-positive real symmetric matrix of a certain distance metric
    train_size : train data sample size
        should be greater than 2
    Returns
    -------
    select_pts: list
        index of selected spetrums as train data, index is zero-based
    remaining_pts: list
        index of remaining spectrums as test data, index is zero-based
    """

    select_pts = []
    remaining_pts = [x for x in range(distance.shape[0])]

    # first select 2 farthest points
    first_2pts = np.unravel_index(np.argmax(distance), distance.shape)
    select_pts.append(first_2pts[0])
    select_pts.append(first_2pts[1])

    # remove the first 2 points from the remaining list
    remaining_pts.remove(first_2pts[0])
    remaining_pts.remove(first_2pts[1])

    for i in range(train_size - 2):
        # find the maximum minimum distance
        select_distance = distance[select_pts, :]
        min_distance = select_distance[:, remaining_pts]
        min_distance = np.min(min_distance, axis=0)
        max_min_distance = np.max(min_distance)

        # select the first point (in case that several distances are the same, choose the first one)
        points = np.argwhere(select_distance == max_min_distance)[:, 1].tolist()
        for point in points:
            if point in select_pts:
                pass
            else:
                select_pts.append(point)
                remaining_pts.remove(point)
                break
    return select_pts, remaining_pts

def spxy(spectra, yvalues, test_size=0.25, metric='euclidean', *args, **kwargs):
    """SPXY Sample Split method
    Parameters
    ----------
    spectra: ndarray, shape of i x j
        i spectrums and j variables (wavelength/wavenumber/ramam shift and so on)
    test_size : float, int
        if float, then round(i x (1-test_size)) spectrums are selected as test data, by default 0.25
        if int, then test_size is directly used as test data size
    metric : str, optional
        The distance metric to use, by default 'euclidean'
        See scipy.spatial.distance.cdist for more infomation
    Returns
    -------
    select_pts: list
        index of selected spetrums as train data, index is zero based
    remaining_pts: list
        index of remaining spectrums as test data, index is zero based
    References
    ---------
    Galvao et al. (2005). A method for calibration and validation subset partitioning.
    Talanta, 67(4), 736-740. (https://www.sciencedirect.com/science/article/pii/S003991400500192X)
    """

    if test_size < 1:
        train_size = round(spectra.shape[0] * (1 - test_size))
    else:
        train_size = spectra.shape[0] - round(test_size)

    if train_size > 2:
        yvalues = yvalues.reshape(yvalues.shape[0], -1)
        distance_spectra = cdist(spectra, spectra, metric=metric, *args, **kwargs)
        distance_y = cdist(yvalues, yvalues, metric=metric, *args, **kwargs)
        distance_spectra = distance_spectra / distance_spectra.max()
        distance_y = distance_y / distance_y.max()

        distance = distance_spectra + distance_y
        select_pts, remaining_pts = max_min_distance_split(distance, train_size)
    else:
        raise ValueError("train sample size should be at least 2")

    return select_pts, remaining_pts

# %%
cal_indices, test_indices = spxy(X_clean, Y_clean, test_size=0.2)
X_cal_spxy, y_cal_spxy = X_clean[cal_indices,:], Y_clean[cal_indices]
X_test_spxy, y_test_spxy = X_clean[test_indices,:], Y_clean[test_indices]

plot_split_cal_test(X_cal_spxy, X_test_spxy, y_cal_spxy, y_test_spxy)

# %%
X_cal, y_cal, X_test, y_test = X_cal_spxy, y_cal_spxy, X_test_spxy, y_test_spxy # let's use SPXY split

# %% [markdown]
# ## Automated pre-processing (nippy)

# %% [markdown]
# As you can see, there are numerous techniques available for preprocessing data, and optimizing these preprocessing steps can often be a complex and time-consuming task. Fortunately, the `nippy` library, an open-source Python module, is specifically designed to streamline and simplify the comparison of various NIRS preprocessing methods.
#
# One of the key features of the `nippy` library is its ability to define preprocessing pipelines through a configuration file, such as `example_pipelines.ini`. You can examine and modify this file to suit your specific needs and preferences.
#
# In the following code, we will leverage the `nippy` library to compute all possible variations of preprocessing pipelines. Afterwards we will train a Partial Least Squares Regression (PLSR) model on a calibration set to identify and select the most effective preprocessing pipeline.

# %%
# jtorniainen // UEF
# 2019, MIT License

import nippy

pipelines = nippy.read_configuration(f'{data_path}/example_pipelines.ini')

# 2. Load data
data = X_cal.T #nippy works with the format where Rows = wavelength, Columns = samples

processed_data = nippy.nippy(wl, data, pipelines)
len(processed_data)
# Out:
# Running pipe 1:
# {'MSC': None, 'SAVGOL': {'deriv_order': 2, 'filter_win': 13, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 2:
# {'MSC': None, 'SAVGOL': {'deriv_order': 1, 'filter_win': 11, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 3:
# {'MSC': None, 'SAVGOL': {'deriv_order': 2, 'filter_win': 5, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 4:
# {'MSC': None, 'SAVGOL': {'deriv_order': 2, 'filter_win': 13, 'poly_order': 2}, 'SNV': {}}
#
# Running pipe 5:
# {'MSC': None, 'SAVGOL': {'deriv_order': 0, 'filter_win': 11, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 6:
# {'MSC': {}, 'SAVGOL': None, 'SNV': None}
#
# Running pipe 7:
# {'MSC': None, 'SAVGOL': {'deriv_order': 0, 'filter_win': 13, 'poly_order': 2}, 'SNV': {}}
#
# Running pipe 8:
# {'MSC': None, 'SAVGOL': {'deriv_order': 1, 'filter_win': 5, 'poly_order': 2}, 'SNV': {}}
#
# Running pipe 9:
# {'MSC': {}, 'SAVGOL': {'deriv_order': 1, 'filter_win': 13, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 10:
# {'MSC': {}, 'SAVGOL': {'deriv_order': 0, 'filter_win': 5, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 11:
# {'MSC': None, 'SAVGOL': {'deriv_order': 0, 'filter_win': 5, 'poly_order': 2}, 'SNV': {}}
#
# Running pipe 12:
# {'MSC': None, 'SAVGOL': {'deriv_order': 1, 'filter_win': 7, 'poly_order': 2}, 'SNV': {}}
#
# Running pipe 13:
# {'MSC': {}, 'SAVGOL': {'deriv_order': 2, 'filter_win': 7, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 14:
# {'MSC': {}, 'SAVGOL': {'deriv_order': 1, 'filter_win': 11, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 15:
# {'MSC': None, 'SAVGOL': {'deriv_order': 0, 'filter_win': 7, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 16:
# {'MSC': None, 'SAVGOL': None, 'SNV': {}}
#
# Running pipe 17:
# {'MSC': None, 'SAVGOL': {'deriv_order': 0, 'filter_win': 13, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 18:
# {'MSC': {}, 'SAVGOL': {'deriv_order': 2, 'filter_win': 11, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 19:
# {'MSC': None, 'SAVGOL': {'deriv_order': 0, 'filter_win': 5, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 20:
# {'MSC': None, 'SAVGOL': {'deriv_order': 2, 'filter_win': 5, 'poly_order': 2}, 'SNV': {}}
#
# Running pipe 21:
# {'MSC': None, 'SAVGOL': {'deriv_order': 2, 'filter_win': 11, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 22:
# {'MSC': None, 'SAVGOL': {'deriv_order': 1, 'filter_win': 5, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 23:
# {'MSC': {}, 'SAVGOL': {'deriv_order': 2, 'filter_win': 13, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 24:
# {'MSC': {}, 'SAVGOL': {'deriv_order': 0, 'filter_win': 7, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 25:
# {'MSC': None, 'SAVGOL': {'deriv_order': 2, 'filter_win': 7, 'poly_order': 2}, 'SNV': {}}
#
# Running pipe 26:
# {'MSC': {}, 'SAVGOL': {'deriv_order': 2, 'filter_win': 5, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 27:
# {'MSC': None, 'SAVGOL': {'deriv_order': 2, 'filter_win': 7, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 28:
# {'MSC': None, 'SAVGOL': {'deriv_order': 1, 'filter_win': 13, 'poly_order': 2}, 'SNV': {}}
#
# Running pipe 29:
# {'MSC': None, 'SAVGOL': None, 'SNV': None}
#
# Running pipe 30:
# {'MSC': None, 'SAVGOL': {'deriv_order': 1, 'filter_win': 13, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 31:
# {'MSC': None, 'SAVGOL': {'deriv_order': 2, 'filter_win': 11, 'poly_order': 2}, 'SNV': {}}
#
# Running pipe 32:
# {'MSC': None, 'SAVGOL': {'deriv_order': 1, 'filter_win': 11, 'poly_order': 2}, 'SNV': {}}
#
# Running pipe 33:
# {'MSC': None, 'SAVGOL': {'deriv_order': 1, 'filter_win': 7, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 34:
# {'MSC': {}, 'SAVGOL': {'deriv_order': 0, 'filter_win': 13, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 35:
# {'MSC': {}, 'SAVGOL': {'deriv_order': 0, 'filter_win': 11, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 36:
# {'MSC': {}, 'SAVGOL': {'deriv_order': 1, 'filter_win': 5, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 37:
# {'MSC': None, 'SAVGOL': {'deriv_order': 0, 'filter_win': 7, 'poly_order': 2}, 'SNV': {}}
#
# Running pipe 38:
# {'MSC': {}, 'SAVGOL': {'deriv_order': 1, 'filter_win': 7, 'poly_order': 2}, 'SNV': None}
#
# Running pipe 39:
# {'MSC': None, 'SAVGOL': {'deriv_order': 0, 'filter_win': 11, 'poly_order': 2}, 'SNV': {}}
# 39

# %%
def plot_spectra(wavelength, raw_spectra, processed_spectra, pipelines, sample_idx=0):
    """
    Plot raw and preprocessed spectra for a given sample index.

    Args:
        wavelength (np.ndarray): Vector of wavelengths.
        raw_spectra (np.ndarray): Raw spectra matrix (wavelength x samples).
        processed_spectra (np.ndarray): Processed spectra matrix.
        sample_idx (int): Index of the sample to plot.
    """
    plt.figure(figsize=(10, 6))
    plt.plot(wavelength, raw_spectra[:, sample_idx], label='Raw Spectrum')
    for i in range(len(processed_spectra)):
        plt.plot(processed_spectra[i][0], processed_spectra[i][1][:, sample_idx], label=pipelines[i])
    plt.xlabel('Wavelength')
    plt.ylabel('Intensity / Absorbance')
    plt.title(f'Spectrum Sample #{sample_idx}')
    plt.legend(bbox_to_anchor=(1,-0.1))
    plt.tight_layout()
    plt.show()

# Example usage:
# wavelength, raw_spectra are your data
# processed_spectra = ... (result of your preprocessing pipeline)
plot_spectra(wl, data, processed_data, pipelines, sample_idx=0)
# Out:
# /tmp/ipykernel_5116/518507249.py:14: MatplotlibDeprecationWarning: Passing label as a length 3 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   plt.plot(processed_spectra[i][0], processed_spectra[i][1][:, sample_idx], label=pipelines[i])
# /tmp/ipykernel_5116/518507249.py:19: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
from sklearn.model_selection import cross_val_score

def evaluate_plsr_across_pipelines(processed_spectra, y, pipelines, max_components=20, cv=5):
    """
    Evaluate PLSR on multiple preprocessed datasets, return the best one based on minimum CV error.
    
    Args:
        processed_spectra (list): List of (wavelength, spectra_matrix) tuples.
        y (np.ndarray): Target vector of shape (n_samples,).
        pipelines (list): List of pipelines.
        max_components (int): Max number of PLS components to try.
        cv (int): Number of CV folds.

    Returns:
        best_pipeline_name (str)
        best_spectra (np.ndarray)
        best_n_components (int)
        cv_errors_all (dict): Mean CV errors for each pipeline
    """
    cv_errors_all = {}
    best_score = np.inf
    best_pipeline_name = None
    best_spectra = None
    best_n_components = None
    best_pipeline_index = None

    for i, (wl, spectra) in enumerate(processed_spectra):
        X = spectra.T  # shape (n_samples, n_features)
        errors = []

        for n_comp in range(1, min(max_components, X.shape[1]) + 1):
            pls = PLSRegression(n_components=n_comp)
            neg_mse = cross_val_score(pls, X, y, cv=cv, scoring='neg_mean_squared_error')
            mean_mse = -np.mean(neg_mse)
            errors.append(mean_mse)

        pipeline_name = str(pipelines[i])
        cv_errors_all[pipeline_name] = errors
        min_error = min(errors)
        if min_error < best_score:
            best_score = min_error
            best_pipeline_name = pipelines[i]
            best_spectra = spectra
            best_pipeline_index = i
            best_n_components = errors.index(min_error) + 1

    return best_pipeline_name, best_spectra, best_n_components, cv_errors_all, best_pipeline_index

# %%
best_pipeline, best_data, n_comp, all_errors, best_pipeline_idx = evaluate_plsr_across_pipelines(
    processed_spectra=processed_data,
    y=y_cal,
    pipelines=pipelines,
    max_components=20,
    cv=5
)

print(f"Best pipeline: {best_pipeline} with {n_comp} components")
# Out:
# Best pipeline: {'MSC': None, 'SAVGOL': {'deriv_order': 2, 'filter_win': 13, 'poly_order': 2}, 'SNV': {}} with 14 components

# %%
X_cal = processed_data[best_pipeline_idx][1].T
wl, X_test = nippy.run_pipeline(wl, X_test.T, best_pipeline)
X_test = X_test.T

# %%
plt.figure(figsize=(12, 6))

# Plot calibration samples
for i in range(X_cal.shape[0]):
    plt.plot(wl, X_cal[i, :], color='blue', alpha=0.3)
    
# Plot test samples
for i in range(X_test.shape[0]):
    plt.plot(wl,X_test[i, :], color='orange', alpha=0.3)

plt.title('Processed Calibration (blue) and Test (orange) samples')
plt.xlabel('Wavelength')
plt.ylabel('Absorbance')
plt.show()

# %% [markdown]
# Next let's look at different spectral calibration models we can build with our data. We will look at PCR, PLSR and NN models.

# %% [markdown]
# ## Spectral calibration

# %% [markdown]
# ### Principal component regression

# %% [markdown]
# Principal Component Regression (PCR) is a technique that combines Principal Component Analysis (PCA) with linear regression. It is particularly useful in situations where predictors are highly correlated or data has noise.

# %%
from sklearn import linear_model
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import root_mean_squared_error
from helperfunctions.plot_functions import r2_score

def simple_regression(X,y):
 
    # Create linear regression object
    regr = linear_model.LinearRegression()
 
    # Fit
    regr.fit(X, y)
 
    # Calibration
    y_c = regr.predict(X)
 
    # Cross-validation
    y_cv = cross_val_predict(regr, X, y, cv=10)
 
    # Calculate scores for calibration and cross-validation
    score_c = r2_score(y, y_c)
    score_cv = r2_score(y, y_cv)
 
    # Calculate mean square error for calibration and cross validation
    rmse_c = root_mean_squared_error(y, y_c)
    rmse_cv = root_mean_squared_error(y, y_cv)
 
    return(y_cv, score_c, score_cv, rmse_c, rmse_cv)

# %%
def pcr(X,y, pc):
 
    # Define the PCA object
    pca = PCA()
 
    # Standardize features by removing the mean and scaling to unit variance
    Xstd = StandardScaler().fit_transform(X)
 
    # Run PCA producing the reduced variable Xred and select the first pc components
    Xreg = pca.fit_transform(Xstd)[:,:pc]
 
    y_cv, score_c, score_cv, mse_c, mse_cv = simple_regression(Xreg, y)
 
    return(y_cv, score_c, score_cv, mse_c, mse_cv)

# %%
npc = 100 # maximum number of principal components
pc = range(1,npc+1,1)
# Define arrays for R^2 and MSE
r2c = np.zeros(npc)
r2cv = np.zeros(npc)
rmsec = np.zeros(npc)
rmsecv = np.zeros(npc)
 
for i in pc:
    predicted, r2c[i-1], r2cv[i-1], rmsec[i-1], rmsecv[i-1] = pcr(X_cal, y_cal, pc=i)

# %%
with plt.style.context(('ggplot')):
    plt.plot(pc, np.sqrt(rmsecv[:]), 'r', label = "RMSECV")
    plt.plot(pc, np.sqrt(rmsec[:]), 'b', label = "RMSEC")
    plt.xlabel("# Principal Components")
    plt.ylabel("RMSE")
    plt.title("Conventional PCR")
    plt.legend()
    plt.show()

# %% [markdown]
# When modelling we want to carefully select the parameters. In the case of PCR we can vary the number of principal components that we use in regression. We always aim for the model that predicts well on unseen data

# %%
pc = np.argmin(rmsecv)

# %%
predicted, r2r, r2cv, mser, mscv = pcr(X_cal,y_cal, pc=pc)
# Regression plot
z = np.polyfit(y_cal, predicted, 1)
with plt.style.context(('ggplot')):
    fig, ax = plt.subplots(figsize=(9, 5))
    ax.scatter(y_cal, predicted, c='red', edgecolors='k')
    ax.plot(y_cal, z[1]+z[0]*y_cal, c='blue', linewidth=1, label = "Regression fit")
    ax.plot(y_cal, y_cal, color='green', linewidth=1, label="x=y", linestyle='--')
    plt.title('Conventional PCR -- $R^2$ (CV): {0:.2f}'.format(r2cv))
    plt.xlabel('Measured Dry Matter')
    plt.ylabel('Predicted Dry Matter')
    plt.legend()
    plt.show()

# %% [markdown]
# Let's also inspect cross-validated predictions and test set predictions

# %%
from sklearn.metrics import root_mean_squared_error

def plot_cv_vs_test(y_cal, y_cv, y_test, y_test_pred, plot_titles=["Cross-Validated Predictions", "Test Predictions"]):
    """
    Plot a comparison of cross-validated vs. test set predictions.

    Parameters
    ----------
    y_cal : array-like, shape (n_samples_cal,)
        True target values for the calibration (training) set.
    y_cv : array-like, shape (n_samples_cal,)
        Cross-validated predicted values for the calibration set.
    y_test : array-like, shape (n_samples_test,)
        True target values for the test set.
    y_test_pred : array-like, shape (n_samples_test,)
        Predicted values for the test set.
    plot_titles : list of str (2), optional
        Plot titles to use.
    """
    # Compute metrics
    r2_cv = r2_score(y_cal, y_cv)
    rmse_cv = root_mean_squared_error(y_cal, y_cv)
    r2_test = r2_score(y_test, y_test_pred)
    rmse_test = root_mean_squared_error(y_test, y_test_pred)

    # Prepare figure
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))

    # Combined axis limits
    all_actual = np.concatenate([y_cal, y_test])
    all_pred = np.concatenate([y_cv, y_test_pred])
    vmin = min(all_actual.min(), all_pred.min())*0.95
    vmax = max(all_actual.max(), all_pred.max())*1.05

    # Plot CV
    axs[0].scatter(y_cal, y_cv, alpha=0.6)
    axs[0].plot([vmin, vmax], [vmin, vmax], 'k--', lw=2)
    axs[0].set_title(plot_titles[0])
    axs[0].set_xlabel('Actual')
    axs[0].set_ylabel('Predicted')
    axs[0].set_aspect('equal', 'box')
    axs[0].text(0.05, 0.95, f"R² = {r2_cv:.2f}\nRMSE = {rmse_cv:.2f}",
                transform=axs[0].transAxes, fontsize=10,
                verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.7))

    # Plot Test
    axs[1].scatter(y_test, y_test_pred, alpha=0.6, color='orange')
    axs[1].plot([vmin, vmax], [vmin, vmax], 'k--', lw=2)
    axs[1].set_title(plot_titles[1])
    axs[1].set_xlabel('Actual')
    axs[1].set_ylabel('Predicted')
    axs[1].set_aspect('equal', 'box')
    axs[1].text(0.05, 0.95, f"R² = {r2_test:.2f}\nRMSE = {rmse_test:.2f}",
                transform=axs[1].transAxes, fontsize=10,
                verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.7))

    # Set same limits
    for ax in axs:
        ax.set_xlim(vmin, vmax)
        ax.set_ylim(vmin, vmax)

    plt.tight_layout()
    plt.show()

# %%
from sklearn import linear_model
from sklearn.model_selection import cross_val_predict

pca = PCA()
standard_scaler_cal = StandardScaler()
Xstd = standard_scaler_cal.fit_transform(X_cal)
Xreg = pca.fit_transform(Xstd)[:,:pc]
# Cross-validation prediction on training set
y_cv = cross_val_predict(linear_model.LinearRegression(), Xreg, y_cal, cv=10)

X_test_std = standard_scaler_cal.transform(X_test)
X_test_reg = pca.transform(X_test_std)[:,:pc]

# Fit model on full calibration set
model = linear_model.LinearRegression()
model.fit(Xreg, y_cal)

# Predict on test set
y_test_pred = model.predict(X_test_reg)

plot_cv_vs_test(y_cal, y_cv, y_test, y_test_pred)

# %% [markdown]
# ### Partial Least Squares Regression

# %% [markdown]
# In the analysis of Near-Infrared (NIR) spectroscopy data, Partial Least Squares Regression (PLSR) is a powerful technique for handling high-dimensional and collinear datasets. PLSR constructs latent variables that not only capture the variance in the predictor variables but also ensure maximum covariance with the response variables. This dual objective makes PLSR particularly effective for predictive modeling in scenarios where traditional regression techniques may struggle.

# %%
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import cross_val_predict
 
# Define PLS object
pls = PLSRegression(n_components=n_comp)
 
# Cross-validation
y_cv = cross_val_predict(pls, X_cal, y_cal, cv=10)
pls.fit(X_cal, y_cal)
y_test_pred = pls.predict(X_test) 

plot_cv_vs_test(y_cal, y_cv, y_test, y_test_pred)

# %%
import joblib

joblib.dump(pls, f'{results_dir}/plsr_model.pkl') # let's save the model
# Out:
# ['results/plsr_model.pkl']

# %% [markdown]
# ## Model diagnostics

# %% [markdown]
# In Partial Least Squares (PLS) regression, selecting the right number of components is crucial to balance underfitting and overfitting. The bias–variance plot shows how training error and cross-validation error change as model complexity increases:
#
# - When using too few components, the model is too simple to capture patterns in the data, resulting in high training and CV error — this is underfitting.
#
# - As you increase the number of components, the model captures more variance in the data, reducing training error.
#
# - Eventually, the model may begin to overfit, capturing noise in the training set. This causes CV error to increase even though training error continues to fall.
#
# The optimal number of PLS components is where the CV error reaches its minimum. This is the point of best generalization to unseen data. If multiple component counts give similar (flat) CV error, prefer the simpler model (with fewer components).

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import cross_val_predict

def optimise_pls_cv_test(X_train, y_train, X_test, y_test, n_comp):
    """
    Run PLS with multiple outputs, using cross-validation to compute MSE for each number of components.
    Also evaluate and plot test set performance.
    
    Parameters
    ----------
    X_train : array-like, shape (n_samples_train, n_features)
        Calibration (training) features.
    y_train : array-like, shape (n_samples_train, n_targets)
        Calibration (training) target(s).
    X_test : array-like, shape (n_samples_test, n_features)
        Test set features.
    y_test : array-like, shape (n_samples_test, n_targets)
        Test set target(s).
    n_comp : int
        Maximum number of PLS components to try.
    
    Returns
    -------
    n_comp: int of optimal number of PLS components
    """
    rmse_cv = []
    rmse_test = []
    rmse_train = []
    components = np.arange(1, n_comp + 1)

    for i in components:
        pls = PLSRegression(n_components=i)
        y_cv = cross_val_predict(pls, X_train, y_train, cv=10)
        rmse_cv.append(root_mean_squared_error(y_train, y_cv))
        pls = PLSRegression(n_components=i)
        pls.fit(X_train, y_train)
        y_train_pred = pls.predict(X_train)
        y_test_pred = pls.predict(X_test)
        rmse_train.append(root_mean_squared_error(y_train, y_train_pred))
        rmse_test.append(root_mean_squared_error(y_test, y_test_pred))
        sys.stdout.write(f"\r{i/n_comp*100:.1f}% completed")
        sys.stdout.flush()
    sys.stdout.write("\n")

    best_idx = int(np.argmin(rmse_cv))
    best_n = best_idx + 1
    print("Suggested number of components:", best_n)

    with plt.style.context("ggplot"):
        plt.figure(figsize=(8, 5))
        plt.plot(components, rmse_train, label='Training RMSE', marker='o', color='green')
        plt.plot(components, rmse_cv, label='CV RMSE', marker='o', color='red')
        plt.plot(components, rmse_test, marker='o', color='blue', label='Test RMSE')
        plt.xlabel('Number of PLS Components')
        plt.ylabel('Root Mean Squared Error')
        plt.title('Bias-Variance Trade-off in PLS')
        plt.legend()
        plt.grid(True)
        plt.show()
    return best_n

# %%
opt_n_comp = optimise_pls_cv_test(X_cal, y_cal, X_test, y_test, n_comp=30)
# Out:
# 3.3% completed
# 100.0% completed
# Suggested number of components: 11

# %% [markdown]
# ## Supervised outlier removal with PLS

# %% [markdown]
# While we're at it, let's look at another technique to address outliers is supervised, meaning the reference values are used to detect such outliers. To identify outliers, we can use methods such as residual analysis, leverage statistics, and Q residuals and T2 statistics. These techniques help pinpoint samples that deviate from the norm and may distort regression results.
#
# The following Python code demonstrates how to detect outliers using PLS regression.

# %%
# Define PLS object
ncomp = opt_n_comp
pls = PLSRegression(n_components=ncomp)
# Fit data
pls.fit(X_cal, y_cal)
 
# Get X scores
T = pls.x_scores_
# Get X loadings
P = pls.x_loadings_
 
# Calculate error array
Err = X_cal - np.dot(T,P.T)
 
# Calculate Q-residuals (sum over the rows of the error array)
Q = np.sum(Err**2, axis=1)
 
# Calculate Hotelling's T-squared (note that data are normalised by default)
Tsq = np.sum((pls.x_scores_/np.std(pls.x_scores_, axis=0))**2, axis=1)

# %%
# set the confidence level
conf = 0.95
 
from scipy.stats import f
# Calculate confidence level for T-squared from the ppf of the F distribution
Tsq_conf =  f.ppf(q=conf, dfn=ncomp, \
            dfd=(X_cal.shape[0]-ncomp))*ncomp*(X_cal.shape[0]-1)/(X_cal.shape[0]-ncomp)
 
# Estimate the confidence level for the Q-residuals
i = np.max(Q)+1
while 1-np.sum(Q>i)/np.sum(Q>0)> conf:
    i -= 1
Q_conf = i

# %%
ax = plt.figure(figsize=(8,4.5))
with plt.style.context(('ggplot')):
    plt.plot(Tsq, Q, 'o')
 
    plt.plot([Tsq_conf,Tsq_conf],[plt.axis()[2],plt.axis()[3]],  '--')
    plt.plot([plt.axis()[0],plt.axis()[1]],[Q_conf,Q_conf],  '--')
    plt.xlabel("Hotelling's T-squared")
    plt.ylabel('Q residuals')
 
plt.show()

# %%
# Calculate RMS distance
rms_values = np.sqrt(Q**2 + Tsq**2)

threshold = np.percentile(rms_values, 95)
outliers = rms_values > threshold
outlier_indices_supervised = np.where(outliers)[0]

# %%
outlier_indices_supervised
# Out:
# array([13, 27, 58, 72, 76, 83, 97])

# %%
# Remove those rows from input and output data
X_train = np.delete(X_cal, outlier_indices_supervised, axis=0)
Y_train = np.delete(y_cal, outlier_indices_supervised, axis=0)

# %%
pls = PLSRegression(n_components=ncomp)

# Cross-validation prediction
y_cv = cross_val_predict(pls, X_train, Y_train, cv=10)

# Calibration prediction
pls.fit(X_train, Y_train)
y_test_pred = pls.predict(X_test)
plot_cv_vs_test(y_cv, Y_train, y_test, y_test_pred)

# %% [markdown]
# ## Deep learning methods (simple convolution)

# %% [markdown]
# Deep learning offers a powerful approach to model complex relationships between spectral data and the properties of interest. Deep learning models with FC layers are essentially multi-layer perceptrons where each layer consists of neurons fully connected to all neurons in the previous layer. By utilizing fully connected (FC) layers, we can build neural network models capable of capturing intricate patterns within the data.

# %%
import tensorflow as tf
from tensorflow.keras import regularizers

model = tf.keras.Sequential([
tf.keras.layers.Dense(224, activation='relu'),
tf.keras.layers.Dense(16, activation='relu'),
tf.keras.layers.Dense(1, activation="linear")])
# Out:
# 2025-11-10 14:15:40.984440: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-10 14:15:41.346131: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762780541.460455    5116 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762780541.497510    5116 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762780541.769322    5116 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762780541.769347    5116 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762780541.769348    5116 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762780541.769349    5116 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-10 14:15:41.797919: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

X_train, X_val, y_train, y_val = train_test_split(X_cal, y_cal,test_size=0.2,random_state=42)
 
scaler = MinMaxScaler()
scaler.fit(X_train)
Xs_train = scaler.transform(X_train)
Xs_val = scaler.transform(X_val)
Xs_test = scaler.transform(X_test)

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"


model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss = "mse", 
              metrics =["accuracy"])
history = model.fit(Xs_train, y_train, epochs=500,
            validation_data=(Xs_val, y_val), 
            verbose=1)
# Out:
# Epoch 1/500
# 2025-11-10 14:15:47.079720: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.0000e+00 - loss: 276.8303 - val_accuracy: 0.0000e+00 - val_loss: 180.3988
# Epoch 2/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0000e+00 - loss: 182.8616 - val_accuracy: 0.0000e+00 - val_loss: 103.2582
# Epoch 3/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 103.1235 - val_accuracy: 0.0000e+00 - val_loss: 42.2707
# Epoch 4/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 41.0024 - val_accuracy: 0.0000e+00 - val_loss: 7.0760
# Epoch 5/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 8.2586 - val_accuracy: 0.0000e+00 - val_loss: 9.5220
# Epoch 6/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 10.1824 - val_accuracy: 0.0000e+00 - val_loss: 24.4929
# Epoch 7/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 18.6658 - val_accuracy: 0.0000e+00 - val_loss: 17.9879
# Epoch 8/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 12.7053 - val_accuracy: 0.0000e+00 - val_loss: 8.2427
# Epoch 9/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0000e+00 - loss: 5.4322 - val_accuracy: 0.0000e+00 - val_loss: 3.5285
# Epoch 10/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 3.9799 - val_accuracy: 0.0000e+00 - val_loss: 3.1570
# Epoch 11/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 5.0039 - val_accuracy: 0.0000e+00 - val_loss: 3.3929
# Epoch 12/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 4.6040 - val_accuracy: 0.0000e+00 - val_loss: 3.0178
# Epoch 13/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 4.7400 - val_accuracy: 0.0000e+00 - val_loss: 2.8432
# Epoch 14/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 3.7255 - val_accuracy: 0.0000e+00 - val_loss: 3.3735
# Epoch 15/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 3.4377 - val_accuracy: 0.0000e+00 - val_loss: 3.7618
# Epoch 16/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 3.6464 - val_accuracy: 0.0000e+00 - val_loss: 3.4420
# Epoch 17/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 3.5304 - val_accuracy: 0.0000e+00 - val_loss: 2.8156
# Epoch 18/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 2.9536 - val_accuracy: 0.0000e+00 - val_loss: 2.4736
# Epoch 19/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 3.1352 - val_accuracy: 0.0000e+00 - val_loss: 2.3548
# Epoch 20/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 2.8719 - val_accuracy: 0.0000e+00 - val_loss: 2.3427
# Epoch 21/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 2.5332 - val_accuracy: 0.0000e+00 - val_loss: 2.4457
# Epoch 22/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 2.6131 - val_accuracy: 0.0000e+00 - val_loss: 2.5296
# Epoch 23/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 2.6673 - val_accuracy: 0.0000e+00 - val_loss: 2.4777
# Epoch 24/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 2.7434 - val_accuracy: 0.0000e+00 - val_loss: 2.2559
# Epoch 25/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 2.7112 - val_accuracy: 0.0000e+00 - val_loss: 2.0479
# Epoch 26/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 2.4831 - val_accuracy: 0.0000e+00 - val_loss: 1.8859
# Epoch 27/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 2.3437 - val_accuracy: 0.0000e+00 - val_loss: 1.8284
# Epoch 28/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 2.2526 - val_accuracy: 0.0000e+00 - val_loss: 1.7916
# Epoch 29/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 2.1540 - val_accuracy: 0.0000e+00 - val_loss: 1.8011
# Epoch 30/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 2.2192 - val_accuracy: 0.0000e+00 - val_loss: 1.8107
# Epoch 31/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 2.2661 - val_accuracy: 0.0000e+00 - val_loss: 1.6863
# Epoch 32/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 2.0387 - val_accuracy: 0.0000e+00 - val_loss: 1.6042
# Epoch 33/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 2.1318 - val_accuracy: 0.0000e+00 - val_loss: 1.5173
# Epoch 34/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 2.0970 - val_accuracy: 0.0000e+00 - val_loss: 1.5140
# Epoch 35/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.9679 - val_accuracy: 0.0000e+00 - val_loss: 1.4855
# Epoch 36/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 2.0235 - val_accuracy: 0.0000e+00 - val_loss: 1.3887
# Epoch 37/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 1.7714 - val_accuracy: 0.0000e+00 - val_loss: 1.3351
# Epoch 38/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.9384 - val_accuracy: 0.0000e+00 - val_loss: 1.2766
# Epoch 39/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 1.8108 - val_accuracy: 0.0000e+00 - val_loss: 1.2310
# Epoch 40/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 1.6796 - val_accuracy: 0.0000e+00 - val_loss: 1.2231
# Epoch 41/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 1.5525 - val_accuracy: 0.0000e+00 - val_loss: 1.2112
# Epoch 42/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.8327 - val_accuracy: 0.0000e+00 - val_loss: 1.1820
# Epoch 43/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.5708 - val_accuracy: 0.0000e+00 - val_loss: 1.1301
# Epoch 44/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 1.5449 - val_accuracy: 0.0000e+00 - val_loss: 1.0805
# Epoch 45/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 1.5435 - val_accuracy: 0.0000e+00 - val_loss: 1.0228
# Epoch 46/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.6875 - val_accuracy: 0.0000e+00 - val_loss: 0.9943
# Epoch 47/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.4303 - val_accuracy: 0.0000e+00 - val_loss: 0.9869
# Epoch 48/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.4472 - val_accuracy: 0.0000e+00 - val_loss: 1.0124
# Epoch 49/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.3972 - val_accuracy: 0.0000e+00 - val_loss: 0.9539
# Epoch 50/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 1.2556 - val_accuracy: 0.0000e+00 - val_loss: 0.8909
# Epoch 51/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 1.3577 - val_accuracy: 0.0000e+00 - val_loss: 0.8663
# Epoch 52/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.4004 - val_accuracy: 0.0000e+00 - val_loss: 0.8415
# Epoch 53/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.2587 - val_accuracy: 0.0000e+00 - val_loss: 0.8501
# Epoch 54/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.2091 - val_accuracy: 0.0000e+00 - val_loss: 0.8480
# Epoch 55/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.2044 - val_accuracy: 0.0000e+00 - val_loss: 0.8060
# Epoch 56/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 1.2167 - val_accuracy: 0.0000e+00 - val_loss: 0.7660
# Epoch 57/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.1124 - val_accuracy: 0.0000e+00 - val_loss: 0.7515
# Epoch 58/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.1985 - val_accuracy: 0.0000e+00 - val_loss: 0.7638
# Epoch 59/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 1.1123 - val_accuracy: 0.0000e+00 - val_loss: 0.7564
# Epoch 60/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.0586 - val_accuracy: 0.0000e+00 - val_loss: 0.7384
# Epoch 61/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.9825 - val_accuracy: 0.0000e+00 - val_loss: 0.7204
# Epoch 62/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.9561 - val_accuracy: 0.0000e+00 - val_loss: 0.6887
# Epoch 63/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.0335 - val_accuracy: 0.0000e+00 - val_loss: 0.6691
# Epoch 64/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.1085 - val_accuracy: 0.0000e+00 - val_loss: 0.6546
# Epoch 65/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.0048 - val_accuracy: 0.0000e+00 - val_loss: 0.6517
# Epoch 66/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.9630 - val_accuracy: 0.0000e+00 - val_loss: 0.6594
# Epoch 67/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.9764 - val_accuracy: 0.0000e+00 - val_loss: 0.6344
# Epoch 68/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.8551 - val_accuracy: 0.0000e+00 - val_loss: 0.6120
# Epoch 69/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.8468 - val_accuracy: 0.0000e+00 - val_loss: 0.6011
# Epoch 70/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.8628 - val_accuracy: 0.0000e+00 - val_loss: 0.6145
# Epoch 71/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.9275 - val_accuracy: 0.0000e+00 - val_loss: 0.5979
# Epoch 72/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.8263 - val_accuracy: 0.0000e+00 - val_loss: 0.5740
# Epoch 73/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.8176 - val_accuracy: 0.0000e+00 - val_loss: 0.5654
# Epoch 74/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.8777 - val_accuracy: 0.0000e+00 - val_loss: 0.5675
# Epoch 75/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.8361 - val_accuracy: 0.0000e+00 - val_loss: 0.5872
# Epoch 76/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.8345 - val_accuracy: 0.0000e+00 - val_loss: 0.5721
# Epoch 77/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.9002 - val_accuracy: 0.0000e+00 - val_loss: 0.5435
# Epoch 78/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.8435 - val_accuracy: 0.0000e+00 - val_loss: 0.5318
# Epoch 79/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.7052 - val_accuracy: 0.0000e+00 - val_loss: 0.5263
# Epoch 80/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.7226 - val_accuracy: 0.0000e+00 - val_loss: 0.5409
# Epoch 81/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.8713 - val_accuracy: 0.0000e+00 - val_loss: 0.5199
# Epoch 82/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.7308 - val_accuracy: 0.0000e+00 - val_loss: 0.5121
# Epoch 83/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.7066 - val_accuracy: 0.0000e+00 - val_loss: 0.5132
# Epoch 84/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.7077 - val_accuracy: 0.0000e+00 - val_loss: 0.5249
# Epoch 85/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.6608 - val_accuracy: 0.0000e+00 - val_loss: 0.5257
# Epoch 86/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.6921 - val_accuracy: 0.0000e+00 - val_loss: 0.4991
# Epoch 87/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.7163 - val_accuracy: 0.0000e+00 - val_loss: 0.4974
# Epoch 88/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.6827 - val_accuracy: 0.0000e+00 - val_loss: 0.4928
# Epoch 89/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.7221 - val_accuracy: 0.0000e+00 - val_loss: 0.4858
# Epoch 90/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.6572 - val_accuracy: 0.0000e+00 - val_loss: 0.4821
# Epoch 91/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.6539 - val_accuracy: 0.0000e+00 - val_loss: 0.4758
# Epoch 92/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.5812 - val_accuracy: 0.0000e+00 - val_loss: 0.4756
# Epoch 93/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.6955 - val_accuracy: 0.0000e+00 - val_loss: 0.4820
# Epoch 94/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.6017 - val_accuracy: 0.0000e+00 - val_loss: 0.4751
# Epoch 95/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.5893 - val_accuracy: 0.0000e+00 - val_loss: 0.4614
# Epoch 96/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.6328 - val_accuracy: 0.0000e+00 - val_loss: 0.4599
# Epoch 97/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.6155 - val_accuracy: 0.0000e+00 - val_loss: 0.4572
# Epoch 98/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.5806 - val_accuracy: 0.0000e+00 - val_loss: 0.4909
# Epoch 99/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.6232 - val_accuracy: 0.0000e+00 - val_loss: 0.4751
# Epoch 100/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.5715 - val_accuracy: 0.0000e+00 - val_loss: 0.4478
# Epoch 101/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.6357 - val_accuracy: 0.0000e+00 - val_loss: 0.4445
# Epoch 102/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.5789 - val_accuracy: 0.0000e+00 - val_loss: 0.4518
# Epoch 103/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.6025 - val_accuracy: 0.0000e+00 - val_loss: 0.4802
# Epoch 104/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.6020 - val_accuracy: 0.0000e+00 - val_loss: 0.4429
# Epoch 105/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.5170 - val_accuracy: 0.0000e+00 - val_loss: 0.4363
# Epoch 106/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.5402 - val_accuracy: 0.0000e+00 - val_loss: 0.4346
# Epoch 107/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.5034 - val_accuracy: 0.0000e+00 - val_loss: 0.4503
# Epoch 108/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.5227 - val_accuracy: 0.0000e+00 - val_loss: 0.4551
# Epoch 109/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.5918 - val_accuracy: 0.0000e+00 - val_loss: 0.4277
# Epoch 110/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.5070 - val_accuracy: 0.0000e+00 - val_loss: 0.4269
# Epoch 111/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.5233 - val_accuracy: 0.0000e+00 - val_loss: 0.4553
# Epoch 112/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.5499 - val_accuracy: 0.0000e+00 - val_loss: 0.4280
# Epoch 113/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.5033 - val_accuracy: 0.0000e+00 - val_loss: 0.4294
# Epoch 114/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4598 - val_accuracy: 0.0000e+00 - val_loss: 0.4231
# Epoch 115/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.5591 - val_accuracy: 0.0000e+00 - val_loss: 0.4853
# Epoch 116/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.5136 - val_accuracy: 0.0000e+00 - val_loss: 0.4466
# Epoch 117/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.5078 - val_accuracy: 0.0000e+00 - val_loss: 0.4146
# Epoch 118/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4355 - val_accuracy: 0.0000e+00 - val_loss: 0.4152
# Epoch 119/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.4988 - val_accuracy: 0.0000e+00 - val_loss: 0.4486
# Epoch 120/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.5433 - val_accuracy: 0.0000e+00 - val_loss: 0.4167
# Epoch 121/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4428 - val_accuracy: 0.0000e+00 - val_loss: 0.4070
# Epoch 122/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4657 - val_accuracy: 0.0000e+00 - val_loss: 0.4133
# Epoch 123/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3877 - val_accuracy: 0.0000e+00 - val_loss: 0.4114
# Epoch 124/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.5092 - val_accuracy: 0.0000e+00 - val_loss: 0.4010
# Epoch 125/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4934 - val_accuracy: 0.0000e+00 - val_loss: 0.4040
# Epoch 126/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.4726 - val_accuracy: 0.0000e+00 - val_loss: 0.4110
# Epoch 127/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4610 - val_accuracy: 0.0000e+00 - val_loss: 0.4026
# Epoch 128/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4324 - val_accuracy: 0.0000e+00 - val_loss: 0.3976
# Epoch 129/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4133 - val_accuracy: 0.0000e+00 - val_loss: 0.4101
# Epoch 130/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4656 - val_accuracy: 0.0000e+00 - val_loss: 0.4247
# Epoch 131/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4744 - val_accuracy: 0.0000e+00 - val_loss: 0.3939
# Epoch 132/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4285 - val_accuracy: 0.0000e+00 - val_loss: 0.3916
# Epoch 133/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4545 - val_accuracy: 0.0000e+00 - val_loss: 0.3935
# Epoch 134/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.4287 - val_accuracy: 0.0000e+00 - val_loss: 0.4093
# Epoch 135/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4342 - val_accuracy: 0.0000e+00 - val_loss: 0.3925
# Epoch 136/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.4593 - val_accuracy: 0.0000e+00 - val_loss: 0.3999
# Epoch 137/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.4028 - val_accuracy: 0.0000e+00 - val_loss: 0.3882
# Epoch 138/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.3877 - val_accuracy: 0.0000e+00 - val_loss: 0.3908
# Epoch 139/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4054 - val_accuracy: 0.0000e+00 - val_loss: 0.4076
# Epoch 140/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3993 - val_accuracy: 0.0000e+00 - val_loss: 0.3875
# Epoch 141/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.3794 - val_accuracy: 0.0000e+00 - val_loss: 0.3833
# Epoch 142/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.4509 - val_accuracy: 0.0000e+00 - val_loss: 0.3873
# Epoch 143/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0000e+00 - loss: 0.3873 - val_accuracy: 0.0000e+00 - val_loss: 0.4092
# Epoch 144/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.3741 - val_accuracy: 0.0000e+00 - val_loss: 0.3824
# Epoch 145/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.3592 - val_accuracy: 0.0000e+00 - val_loss: 0.3828
# Epoch 146/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.3839 - val_accuracy: 0.0000e+00 - val_loss: 0.4308
# Epoch 147/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.4244 - val_accuracy: 0.0000e+00 - val_loss: 0.4274
# Epoch 148/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.3248 - val_accuracy: 0.0000e+00 - val_loss: 0.3813
# Epoch 149/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3776 - val_accuracy: 0.0000e+00 - val_loss: 0.3773
# Epoch 150/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.4093 - val_accuracy: 0.0000e+00 - val_loss: 0.3949
# Epoch 151/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3700 - val_accuracy: 0.0000e+00 - val_loss: 0.3776
# Epoch 152/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3259 - val_accuracy: 0.0000e+00 - val_loss: 0.3898
# Epoch 153/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3652 - val_accuracy: 0.0000e+00 - val_loss: 0.3886
# Epoch 154/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3437 - val_accuracy: 0.0000e+00 - val_loss: 0.4193
# Epoch 155/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3451 - val_accuracy: 0.0000e+00 - val_loss: 0.4088
# Epoch 156/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.3345 - val_accuracy: 0.0000e+00 - val_loss: 0.3861
# Epoch 157/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.3234 - val_accuracy: 0.0000e+00 - val_loss: 0.3895
# Epoch 158/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3828 - val_accuracy: 0.0000e+00 - val_loss: 0.3925
# Epoch 159/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3325 - val_accuracy: 0.0000e+00 - val_loss: 0.3960
# Epoch 160/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3731 - val_accuracy: 0.0000e+00 - val_loss: 0.3855
# Epoch 161/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3041 - val_accuracy: 0.0000e+00 - val_loss: 0.3909
# Epoch 162/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3310 - val_accuracy: 0.0000e+00 - val_loss: 0.4095
# Epoch 163/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3536 - val_accuracy: 0.0000e+00 - val_loss: 0.3810
# Epoch 164/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.3289 - val_accuracy: 0.0000e+00 - val_loss: 0.3838
# Epoch 165/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.3338 - val_accuracy: 0.0000e+00 - val_loss: 0.3917
# Epoch 166/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3461 - val_accuracy: 0.0000e+00 - val_loss: 0.3969
# Epoch 167/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3153 - val_accuracy: 0.0000e+00 - val_loss: 0.3749
# Epoch 168/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3417 - val_accuracy: 0.0000e+00 - val_loss: 0.3751
# Epoch 169/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3422 - val_accuracy: 0.0000e+00 - val_loss: 0.3902
# Epoch 170/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.3029 - val_accuracy: 0.0000e+00 - val_loss: 0.4089
# Epoch 171/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.2778 - val_accuracy: 0.0000e+00 - val_loss: 0.3738
# Epoch 172/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.3272 - val_accuracy: 0.0000e+00 - val_loss: 0.3778
# Epoch 173/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3442 - val_accuracy: 0.0000e+00 - val_loss: 0.3937
# Epoch 174/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.3377 - val_accuracy: 0.0000e+00 - val_loss: 0.3877
# Epoch 175/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.2966 - val_accuracy: 0.0000e+00 - val_loss: 0.3730
# Epoch 176/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2888 - val_accuracy: 0.0000e+00 - val_loss: 0.3713
# Epoch 177/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2982 - val_accuracy: 0.0000e+00 - val_loss: 0.3745
# Epoch 178/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2953 - val_accuracy: 0.0000e+00 - val_loss: 0.3709
# Epoch 179/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3246 - val_accuracy: 0.0000e+00 - val_loss: 0.3664
# Epoch 180/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.3159 - val_accuracy: 0.0000e+00 - val_loss: 0.3625
# Epoch 181/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2990 - val_accuracy: 0.0000e+00 - val_loss: 0.3639
# Epoch 182/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3370 - val_accuracy: 0.0000e+00 - val_loss: 0.3751
# Epoch 183/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2998 - val_accuracy: 0.0000e+00 - val_loss: 0.3670
# Epoch 184/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.3006 - val_accuracy: 0.0000e+00 - val_loss: 0.3742
# Epoch 185/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2817 - val_accuracy: 0.0000e+00 - val_loss: 0.3669
# Epoch 186/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2690 - val_accuracy: 0.0000e+00 - val_loss: 0.3775
# Epoch 187/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.2752 - val_accuracy: 0.0000e+00 - val_loss: 0.3647
# Epoch 188/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2504 - val_accuracy: 0.0000e+00 - val_loss: 0.3661
# Epoch 189/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2856 - val_accuracy: 0.0000e+00 - val_loss: 0.3685
# Epoch 190/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2857 - val_accuracy: 0.0000e+00 - val_loss: 0.3674
# Epoch 191/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2540 - val_accuracy: 0.0000e+00 - val_loss: 0.3674
# Epoch 192/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2895 - val_accuracy: 0.0000e+00 - val_loss: 0.3569
# Epoch 193/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.2988 - val_accuracy: 0.0000e+00 - val_loss: 0.4057
# Epoch 194/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2943 - val_accuracy: 0.0000e+00 - val_loss: 0.3619
# Epoch 195/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3198 - val_accuracy: 0.0000e+00 - val_loss: 0.3509
# Epoch 196/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2543 - val_accuracy: 0.0000e+00 - val_loss: 0.4036
# Epoch 197/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.3238 - val_accuracy: 0.0000e+00 - val_loss: 0.3532
# Epoch 198/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2711 - val_accuracy: 0.0000e+00 - val_loss: 0.3532
# Epoch 199/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2497 - val_accuracy: 0.0000e+00 - val_loss: 0.3659
# Epoch 200/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2821 - val_accuracy: 0.0000e+00 - val_loss: 0.3753
# Epoch 201/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2767 - val_accuracy: 0.0000e+00 - val_loss: 0.3552
# Epoch 202/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2961 - val_accuracy: 0.0000e+00 - val_loss: 0.3537
# Epoch 203/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.2451 - val_accuracy: 0.0000e+00 - val_loss: 0.3899
# Epoch 204/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2912 - val_accuracy: 0.0000e+00 - val_loss: 0.3511
# Epoch 205/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2509 - val_accuracy: 0.0000e+00 - val_loss: 0.3529
# Epoch 206/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2620 - val_accuracy: 0.0000e+00 - val_loss: 0.3741
# Epoch 207/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2622 - val_accuracy: 0.0000e+00 - val_loss: 0.3539
# Epoch 208/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2434 - val_accuracy: 0.0000e+00 - val_loss: 0.3573
# Epoch 209/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.2448 - val_accuracy: 0.0000e+00 - val_loss: 0.3602
# Epoch 210/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.2289 - val_accuracy: 0.0000e+00 - val_loss: 0.3580
# Epoch 211/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2423 - val_accuracy: 0.0000e+00 - val_loss: 0.3531
# Epoch 212/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2646 - val_accuracy: 0.0000e+00 - val_loss: 0.3521
# Epoch 213/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2661 - val_accuracy: 0.0000e+00 - val_loss: 0.3546
# Epoch 214/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2070 - val_accuracy: 0.0000e+00 - val_loss: 0.3523
# Epoch 215/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.2366 - val_accuracy: 0.0000e+00 - val_loss: 0.3522
# Epoch 216/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2322 - val_accuracy: 0.0000e+00 - val_loss: 0.3496
# Epoch 217/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.2597 - val_accuracy: 0.0000e+00 - val_loss: 0.3483
# Epoch 218/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.2674 - val_accuracy: 0.0000e+00 - val_loss: 0.3616
# Epoch 219/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2307 - val_accuracy: 0.0000e+00 - val_loss: 0.3501
# Epoch 220/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2455 - val_accuracy: 0.0000e+00 - val_loss: 0.3563
# Epoch 221/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.2414 - val_accuracy: 0.0000e+00 - val_loss: 0.3572
# Epoch 222/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2493 - val_accuracy: 0.0000e+00 - val_loss: 0.3560
# Epoch 223/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2482 - val_accuracy: 0.0000e+00 - val_loss: 0.3554
# Epoch 224/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2435 - val_accuracy: 0.0000e+00 - val_loss: 0.3587
# Epoch 225/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2142 - val_accuracy: 0.0000e+00 - val_loss: 0.3524
# Epoch 226/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2456 - val_accuracy: 0.0000e+00 - val_loss: 0.3527
# Epoch 227/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.2421 - val_accuracy: 0.0000e+00 - val_loss: 0.3508
# Epoch 228/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2280 - val_accuracy: 0.0000e+00 - val_loss: 0.3547
# Epoch 229/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.2629 - val_accuracy: 0.0000e+00 - val_loss: 0.3513
# Epoch 230/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2436 - val_accuracy: 0.0000e+00 - val_loss: 0.3610
# Epoch 231/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2551 - val_accuracy: 0.0000e+00 - val_loss: 0.3574
# Epoch 232/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2389 - val_accuracy: 0.0000e+00 - val_loss: 0.3558
# Epoch 233/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2326 - val_accuracy: 0.0000e+00 - val_loss: 0.3549
# Epoch 234/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2285 - val_accuracy: 0.0000e+00 - val_loss: 0.3625
# Epoch 235/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2431 - val_accuracy: 0.0000e+00 - val_loss: 0.3497
# Epoch 236/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2367 - val_accuracy: 0.0000e+00 - val_loss: 0.3493
# Epoch 237/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2201 - val_accuracy: 0.0000e+00 - val_loss: 0.3476
# Epoch 238/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.2237 - val_accuracy: 0.0000e+00 - val_loss: 0.3516
# Epoch 239/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1951 - val_accuracy: 0.0000e+00 - val_loss: 0.3452
# Epoch 240/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0000e+00 - loss: 0.2537 - val_accuracy: 0.0000e+00 - val_loss: 0.3444
# Epoch 241/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2103 - val_accuracy: 0.0000e+00 - val_loss: 0.3441
# Epoch 242/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2216 - val_accuracy: 0.0000e+00 - val_loss: 0.3520
# Epoch 243/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2404 - val_accuracy: 0.0000e+00 - val_loss: 0.3557
# Epoch 244/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.2072 - val_accuracy: 0.0000e+00 - val_loss: 0.3408
# Epoch 245/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2366 - val_accuracy: 0.0000e+00 - val_loss: 0.3415
# Epoch 246/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2062 - val_accuracy: 0.0000e+00 - val_loss: 0.3440
# Epoch 247/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2132 - val_accuracy: 0.0000e+00 - val_loss: 0.3442
# Epoch 248/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2265 - val_accuracy: 0.0000e+00 - val_loss: 0.3490
# Epoch 249/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1980 - val_accuracy: 0.0000e+00 - val_loss: 0.3440
# Epoch 250/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.2098 - val_accuracy: 0.0000e+00 - val_loss: 0.3420
# Epoch 251/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2027 - val_accuracy: 0.0000e+00 - val_loss: 0.3479
# Epoch 252/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2088 - val_accuracy: 0.0000e+00 - val_loss: 0.3451
# Epoch 253/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1985 - val_accuracy: 0.0000e+00 - val_loss: 0.3396
# Epoch 254/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2170 - val_accuracy: 0.0000e+00 - val_loss: 0.3561
# Epoch 255/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.2155 - val_accuracy: 0.0000e+00 - val_loss: 0.3427
# Epoch 256/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.2220 - val_accuracy: 0.0000e+00 - val_loss: 0.3437
# Epoch 257/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2011 - val_accuracy: 0.0000e+00 - val_loss: 0.3761
# Epoch 258/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.2087 - val_accuracy: 0.0000e+00 - val_loss: 0.3437
# Epoch 259/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2236 - val_accuracy: 0.0000e+00 - val_loss: 0.3454
# Epoch 260/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0000e+00 - loss: 0.2146 - val_accuracy: 0.0000e+00 - val_loss: 0.3613
# Epoch 261/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0000e+00 - loss: 0.2436 - val_accuracy: 0.0000e+00 - val_loss: 0.3428
# Epoch 262/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0000e+00 - loss: 0.2120 - val_accuracy: 0.0000e+00 - val_loss: 0.3443
# Epoch 263/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.0000e+00 - loss: 0.2087 - val_accuracy: 0.0000e+00 - val_loss: 0.3445
# Epoch 264/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.2033 - val_accuracy: 0.0000e+00 - val_loss: 0.3417
# Epoch 265/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0000e+00 - loss: 0.1842 - val_accuracy: 0.0000e+00 - val_loss: 0.3452
# Epoch 266/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0000e+00 - loss: 0.1829 - val_accuracy: 0.0000e+00 - val_loss: 0.3392
# Epoch 267/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.0000e+00 - loss: 0.1923 - val_accuracy: 0.0000e+00 - val_loss: 0.3470
# Epoch 268/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0000e+00 - loss: 0.1976 - val_accuracy: 0.0000e+00 - val_loss: 0.3415
# Epoch 269/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0000e+00 - loss: 0.1887 - val_accuracy: 0.0000e+00 - val_loss: 0.3347
# Epoch 270/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0000e+00 - loss: 0.1965 - val_accuracy: 0.0000e+00 - val_loss: 0.3477
# Epoch 271/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1918 - val_accuracy: 0.0000e+00 - val_loss: 0.3399
# Epoch 272/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2018 - val_accuracy: 0.0000e+00 - val_loss: 0.3349
# Epoch 273/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2245 - val_accuracy: 0.0000e+00 - val_loss: 0.3396
# Epoch 274/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1974 - val_accuracy: 0.0000e+00 - val_loss: 0.3442
# Epoch 275/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1801 - val_accuracy: 0.0000e+00 - val_loss: 0.3394
# Epoch 276/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2313 - val_accuracy: 0.0000e+00 - val_loss: 0.3324
# Epoch 277/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1956 - val_accuracy: 0.0000e+00 - val_loss: 0.3529
# Epoch 278/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2028 - val_accuracy: 0.0000e+00 - val_loss: 0.3297
# Epoch 279/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2066 - val_accuracy: 0.0000e+00 - val_loss: 0.3421
# Epoch 280/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1957 - val_accuracy: 0.0000e+00 - val_loss: 0.3280
# Epoch 281/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2250 - val_accuracy: 0.0000e+00 - val_loss: 0.3284
# Epoch 282/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.1773 - val_accuracy: 0.0000e+00 - val_loss: 0.3585
# Epoch 283/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1956 - val_accuracy: 0.0000e+00 - val_loss: 0.3290
# Epoch 284/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.2078 - val_accuracy: 0.0000e+00 - val_loss: 0.3323
# Epoch 285/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2163 - val_accuracy: 0.0000e+00 - val_loss: 0.3398
# Epoch 286/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2122 - val_accuracy: 0.0000e+00 - val_loss: 0.3290
# Epoch 287/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2043 - val_accuracy: 0.0000e+00 - val_loss: 0.3377
# Epoch 288/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1998 - val_accuracy: 0.0000e+00 - val_loss: 0.3273
# Epoch 289/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1897 - val_accuracy: 0.0000e+00 - val_loss: 0.3298
# Epoch 290/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1664 - val_accuracy: 0.0000e+00 - val_loss: 0.3298
# Epoch 291/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1986 - val_accuracy: 0.0000e+00 - val_loss: 0.3375
# Epoch 292/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0000e+00 - loss: 0.1682 - val_accuracy: 0.0000e+00 - val_loss: 0.3335
# Epoch 293/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2034 - val_accuracy: 0.0000e+00 - val_loss: 0.3329
# Epoch 294/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1958 - val_accuracy: 0.0000e+00 - val_loss: 0.3602
# Epoch 295/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.2037 - val_accuracy: 0.0000e+00 - val_loss: 0.3340
# Epoch 296/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1900 - val_accuracy: 0.0000e+00 - val_loss: 0.3365
# Epoch 297/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1975 - val_accuracy: 0.0000e+00 - val_loss: 0.3357
# Epoch 298/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.0000e+00 - loss: 0.1973 - val_accuracy: 0.0000e+00 - val_loss: 0.3396
# Epoch 299/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.1722 - val_accuracy: 0.0000e+00 - val_loss: 0.3484
# Epoch 300/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0000e+00 - loss: 0.1625 - val_accuracy: 0.0000e+00 - val_loss: 0.3380
# Epoch 301/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0000e+00 - loss: 0.1913 - val_accuracy: 0.0000e+00 - val_loss: 0.3457
# Epoch 302/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0000e+00 - loss: 0.1813 - val_accuracy: 0.0000e+00 - val_loss: 0.3411
# Epoch 303/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.1822 - val_accuracy: 0.0000e+00 - val_loss: 0.3441
# Epoch 304/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2009 - val_accuracy: 0.0000e+00 - val_loss: 0.3506
# Epoch 305/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1996 - val_accuracy: 0.0000e+00 - val_loss: 0.3393
# Epoch 306/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1882 - val_accuracy: 0.0000e+00 - val_loss: 0.3484
# Epoch 307/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.1984 - val_accuracy: 0.0000e+00 - val_loss: 0.3414
# Epoch 308/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.1805 - val_accuracy: 0.0000e+00 - val_loss: 0.3582
# Epoch 309/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1689 - val_accuracy: 0.0000e+00 - val_loss: 0.3426
# Epoch 310/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1777 - val_accuracy: 0.0000e+00 - val_loss: 0.3584
# Epoch 311/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1811 - val_accuracy: 0.0000e+00 - val_loss: 0.3462
# Epoch 312/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.1924 - val_accuracy: 0.0000e+00 - val_loss: 0.3377
# Epoch 313/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0000e+00 - loss: 0.1716 - val_accuracy: 0.0000e+00 - val_loss: 0.3345
# Epoch 314/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.2159 - val_accuracy: 0.0000e+00 - val_loss: 0.3430
# Epoch 315/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1855 - val_accuracy: 0.0000e+00 - val_loss: 0.3359
# Epoch 316/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1907 - val_accuracy: 0.0000e+00 - val_loss: 0.3370
# Epoch 317/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1775 - val_accuracy: 0.0000e+00 - val_loss: 0.3404
# Epoch 318/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1803 - val_accuracy: 0.0000e+00 - val_loss: 0.3352
# Epoch 319/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.1783 - val_accuracy: 0.0000e+00 - val_loss: 0.3533
# Epoch 320/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1618 - val_accuracy: 0.0000e+00 - val_loss: 0.3293
# Epoch 321/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1904 - val_accuracy: 0.0000e+00 - val_loss: 0.3262
# Epoch 322/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1891 - val_accuracy: 0.0000e+00 - val_loss: 0.3324
# Epoch 323/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1792 - val_accuracy: 0.0000e+00 - val_loss: 0.3268
# Epoch 324/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1973 - val_accuracy: 0.0000e+00 - val_loss: 0.3274
# Epoch 325/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1747 - val_accuracy: 0.0000e+00 - val_loss: 0.3794
# Epoch 326/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.2072 - val_accuracy: 0.0000e+00 - val_loss: 0.3245
# Epoch 327/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1704 - val_accuracy: 0.0000e+00 - val_loss: 0.3254
# Epoch 328/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1579 - val_accuracy: 0.0000e+00 - val_loss: 0.3604
# Epoch 329/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1696 - val_accuracy: 0.0000e+00 - val_loss: 0.3267
# Epoch 330/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1869 - val_accuracy: 0.0000e+00 - val_loss: 0.3453
# Epoch 331/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.2062 - val_accuracy: 0.0000e+00 - val_loss: 0.3656
# Epoch 332/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0000e+00 - loss: 0.1848 - val_accuracy: 0.0000e+00 - val_loss: 0.3410
# Epoch 333/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1832 - val_accuracy: 0.0000e+00 - val_loss: 0.3588
# Epoch 334/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1977 - val_accuracy: 0.0000e+00 - val_loss: 0.3371
# Epoch 335/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1932 - val_accuracy: 0.0000e+00 - val_loss: 0.3391
# Epoch 336/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1896 - val_accuracy: 0.0000e+00 - val_loss: 0.3743
# Epoch 337/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1949 - val_accuracy: 0.0000e+00 - val_loss: 0.3368
# Epoch 338/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1825 - val_accuracy: 0.0000e+00 - val_loss: 0.3383
# Epoch 339/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1752 - val_accuracy: 0.0000e+00 - val_loss: 0.3707
# Epoch 340/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1701 - val_accuracy: 0.0000e+00 - val_loss: 0.3343
# Epoch 341/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1714 - val_accuracy: 0.0000e+00 - val_loss: 0.3347
# Epoch 342/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1671 - val_accuracy: 0.0000e+00 - val_loss: 0.3540
# Epoch 343/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1626 - val_accuracy: 0.0000e+00 - val_loss: 0.3367
# Epoch 344/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1914 - val_accuracy: 0.0000e+00 - val_loss: 0.3379
# Epoch 345/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1657 - val_accuracy: 0.0000e+00 - val_loss: 0.3373
# Epoch 346/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1539 - val_accuracy: 0.0000e+00 - val_loss: 0.3287
# Epoch 347/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1702 - val_accuracy: 0.0000e+00 - val_loss: 0.3337
# Epoch 348/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1691 - val_accuracy: 0.0000e+00 - val_loss: 0.3358
# Epoch 349/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.1651 - val_accuracy: 0.0000e+00 - val_loss: 0.3417
# Epoch 350/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1603 - val_accuracy: 0.0000e+00 - val_loss: 0.3362
# Epoch 351/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1406 - val_accuracy: 0.0000e+00 - val_loss: 0.3339
# Epoch 352/500
# ...
# Epoch 384/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1493 - val_accuracy: 0.0000e+00 - val_loss: 0.3520
# Epoch 385/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1550 - val_accuracy: 0.0000e+00 - val_loss: 0.3261
# Epoch 386/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.1624 - val_accuracy: 0.0000e+00 - val_loss: 0.3354
# Epoch 387/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1504 - val_accuracy: 0.0000e+00 - val_loss: 0.3334
# Epoch 388/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1473 - val_accuracy: 0.0000e+00 - val_loss: 0.3246
# Epoch 389/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1450 - val_accuracy: 0.0000e+00 - val_loss: 0.3486
# Epoch 390/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1435 - val_accuracy: 0.0000e+00 - val_loss: 0.3327
# Epoch 391/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1404 - val_accuracy: 0.0000e+00 - val_loss: 0.3758
# Epoch 392/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1679 - val_accuracy: 0.0000e+00 - val_loss: 0.3301
# Epoch 393/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1515 - val_accuracy: 0.0000e+00 - val_loss: 0.3375
# Epoch 394/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1660 - val_accuracy: 0.0000e+00 - val_loss: 0.3302
# Epoch 395/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1548 - val_accuracy: 0.0000e+00 - val_loss: 0.3268
# Epoch 396/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1426 - val_accuracy: 0.0000e+00 - val_loss: 0.3858
# Epoch 397/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1788 - val_accuracy: 0.0000e+00 - val_loss: 0.3245
# Epoch 398/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1570 - val_accuracy: 0.0000e+00 - val_loss: 0.3251
# Epoch 399/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1536 - val_accuracy: 0.0000e+00 - val_loss: 0.3423
# Epoch 400/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1624 - val_accuracy: 0.0000e+00 - val_loss: 0.3278
# Epoch 401/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.1564 - val_accuracy: 0.0000e+00 - val_loss: 0.3281
# Epoch 402/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1245 - val_accuracy: 0.0000e+00 - val_loss: 0.3331
# Epoch 403/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1409 - val_accuracy: 0.0000e+00 - val_loss: 0.3267
# Epoch 404/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1398 - val_accuracy: 0.0000e+00 - val_loss: 0.3284
# Epoch 405/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1497 - val_accuracy: 0.0000e+00 - val_loss: 0.3337
# Epoch 406/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1544 - val_accuracy: 0.0000e+00 - val_loss: 0.3430
# Epoch 407/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.1285 - val_accuracy: 0.0000e+00 - val_loss: 0.3417
# Epoch 408/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.1602 - val_accuracy: 0.0000e+00 - val_loss: 0.3522
# Epoch 409/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1533 - val_accuracy: 0.0000e+00 - val_loss: 0.3330
# Epoch 410/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1507 - val_accuracy: 0.0000e+00 - val_loss: 0.3317
# Epoch 411/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1679 - val_accuracy: 0.0000e+00 - val_loss: 0.3368
# Epoch 412/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1407 - val_accuracy: 0.0000e+00 - val_loss: 0.3341
# Epoch 413/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1625 - val_accuracy: 0.0000e+00 - val_loss: 0.3536
# Epoch 414/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1608 - val_accuracy: 0.0000e+00 - val_loss: 0.3307
# Epoch 415/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1379 - val_accuracy: 0.0000e+00 - val_loss: 0.3335
# Epoch 416/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1207 - val_accuracy: 0.0000e+00 - val_loss: 0.3305
# Epoch 417/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1403 - val_accuracy: 0.0000e+00 - val_loss: 0.3323
# Epoch 418/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1327 - val_accuracy: 0.0000e+00 - val_loss: 0.3333
# Epoch 419/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1495 - val_accuracy: 0.0000e+00 - val_loss: 0.3385
# Epoch 420/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1418 - val_accuracy: 0.0000e+00 - val_loss: 0.3374
# Epoch 421/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1308 - val_accuracy: 0.0000e+00 - val_loss: 0.3308
# Epoch 422/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1605 - val_accuracy: 0.0000e+00 - val_loss: 0.3562
# Epoch 423/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1488 - val_accuracy: 0.0000e+00 - val_loss: 0.3300
# Epoch 424/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1447 - val_accuracy: 0.0000e+00 - val_loss: 0.3500
# Epoch 425/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1570 - val_accuracy: 0.0000e+00 - val_loss: 0.3317
# Epoch 426/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1373 - val_accuracy: 0.0000e+00 - val_loss: 0.3303
# Epoch 427/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1319 - val_accuracy: 0.0000e+00 - val_loss: 0.3381
# Epoch 428/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1490 - val_accuracy: 0.0000e+00 - val_loss: 0.3328
# Epoch 429/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1412 - val_accuracy: 0.0000e+00 - val_loss: 0.3445
# Epoch 430/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1438 - val_accuracy: 0.0000e+00 - val_loss: 0.3299
# Epoch 431/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1396 - val_accuracy: 0.0000e+00 - val_loss: 0.3269
# Epoch 432/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1381 - val_accuracy: 0.0000e+00 - val_loss: 0.3285
# Epoch 433/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1278 - val_accuracy: 0.0000e+00 - val_loss: 0.3289
# Epoch 434/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1428 - val_accuracy: 0.0000e+00 - val_loss: 0.3377
# Epoch 435/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.0000e+00 - loss: 0.1170 - val_accuracy: 0.0000e+00 - val_loss: 0.3350
# Epoch 436/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1339 - val_accuracy: 0.0000e+00 - val_loss: 0.3343
# Epoch 437/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1401 - val_accuracy: 0.0000e+00 - val_loss: 0.3430
# Epoch 438/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1217 - val_accuracy: 0.0000e+00 - val_loss: 0.3282
# Epoch 439/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.1266 - val_accuracy: 0.0000e+00 - val_loss: 0.3505
# Epoch 440/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1356 - val_accuracy: 0.0000e+00 - val_loss: 0.3257
# Epoch 441/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1245 - val_accuracy: 0.0000e+00 - val_loss: 0.3364
# Epoch 442/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1370 - val_accuracy: 0.0000e+00 - val_loss: 0.3316
# Epoch 443/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1210 - val_accuracy: 0.0000e+00 - val_loss: 0.3296
# Epoch 444/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1230 - val_accuracy: 0.0000e+00 - val_loss: 0.3382
# Epoch 445/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1440 - val_accuracy: 0.0000e+00 - val_loss: 0.3303
# Epoch 446/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1185 - val_accuracy: 0.0000e+00 - val_loss: 0.3613
# Epoch 447/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1500 - val_accuracy: 0.0000e+00 - val_loss: 0.3289
# Epoch 448/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1227 - val_accuracy: 0.0000e+00 - val_loss: 0.3536
# Epoch 449/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1283 - val_accuracy: 0.0000e+00 - val_loss: 0.3328
# Epoch 450/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1275 - val_accuracy: 0.0000e+00 - val_loss: 0.3339
# Epoch 451/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1405 - val_accuracy: 0.0000e+00 - val_loss: 0.3376
# Epoch 452/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1259 - val_accuracy: 0.0000e+00 - val_loss: 0.3291
# Epoch 453/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1224 - val_accuracy: 0.0000e+00 - val_loss: 0.3298
# Epoch 454/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1350 - val_accuracy: 0.0000e+00 - val_loss: 0.3290
# Epoch 455/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1176 - val_accuracy: 0.0000e+00 - val_loss: 0.3262
# Epoch 456/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1317 - val_accuracy: 0.0000e+00 - val_loss: 0.3520
# Epoch 457/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1485 - val_accuracy: 0.0000e+00 - val_loss: 0.3327
# Epoch 458/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1464 - val_accuracy: 0.0000e+00 - val_loss: 0.3330
# Epoch 459/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.1142 - val_accuracy: 0.0000e+00 - val_loss: 0.3401
# Epoch 460/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1207 - val_accuracy: 0.0000e+00 - val_loss: 0.3240
# Epoch 461/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1373 - val_accuracy: 0.0000e+00 - val_loss: 0.3315
# Epoch 462/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1392 - val_accuracy: 0.0000e+00 - val_loss: 0.3283
# Epoch 463/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1126 - val_accuracy: 0.0000e+00 - val_loss: 0.3377
# Epoch 464/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1265 - val_accuracy: 0.0000e+00 - val_loss: 0.3292
# Epoch 465/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1265 - val_accuracy: 0.0000e+00 - val_loss: 0.3259
# Epoch 466/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1121 - val_accuracy: 0.0000e+00 - val_loss: 0.3665
# Epoch 467/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1433 - val_accuracy: 0.0000e+00 - val_loss: 0.3228
# Epoch 468/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1234 - val_accuracy: 0.0000e+00 - val_loss: 0.3319
# Epoch 469/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1464 - val_accuracy: 0.0000e+00 - val_loss: 0.3387
# Epoch 470/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1219 - val_accuracy: 0.0000e+00 - val_loss: 0.3262
# Epoch 471/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1318 - val_accuracy: 0.0000e+00 - val_loss: 0.3381
# Epoch 472/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1264 - val_accuracy: 0.0000e+00 - val_loss: 0.3224
# Epoch 473/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1321 - val_accuracy: 0.0000e+00 - val_loss: 0.3382
# Epoch 474/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1393 - val_accuracy: 0.0000e+00 - val_loss: 0.3295
# Epoch 475/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1388 - val_accuracy: 0.0000e+00 - val_loss: 0.3283
# Epoch 476/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1263 - val_accuracy: 0.0000e+00 - val_loss: 0.3433
# Epoch 477/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0000e+00 - loss: 0.1111 - val_accuracy: 0.0000e+00 - val_loss: 0.3312
# Epoch 478/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1181 - val_accuracy: 0.0000e+00 - val_loss: 0.3404
# Epoch 479/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1292 - val_accuracy: 0.0000e+00 - val_loss: 0.3382
# Epoch 480/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.1128 - val_accuracy: 0.0000e+00 - val_loss: 0.3408
# Epoch 481/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1200 - val_accuracy: 0.0000e+00 - val_loss: 0.3417
# Epoch 482/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1320 - val_accuracy: 0.0000e+00 - val_loss: 0.3418
# Epoch 483/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1216 - val_accuracy: 0.0000e+00 - val_loss: 0.3410
# Epoch 484/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1224 - val_accuracy: 0.0000e+00 - val_loss: 0.3471
# Epoch 485/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1188 - val_accuracy: 0.0000e+00 - val_loss: 0.3403
# Epoch 486/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1016 - val_accuracy: 0.0000e+00 - val_loss: 0.3424
# Epoch 487/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1146 - val_accuracy: 0.0000e+00 - val_loss: 0.3427
# Epoch 488/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1080 - val_accuracy: 0.0000e+00 - val_loss: 0.3611
# Epoch 489/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1329 - val_accuracy: 0.0000e+00 - val_loss: 0.3388
# Epoch 490/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1254 - val_accuracy: 0.0000e+00 - val_loss: 0.3701
# Epoch 491/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1515 - val_accuracy: 0.0000e+00 - val_loss: 0.3355
# Epoch 492/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1356 - val_accuracy: 0.0000e+00 - val_loss: 0.3368
# Epoch 493/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1217 - val_accuracy: 0.0000e+00 - val_loss: 0.3469
# Epoch 494/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1241 - val_accuracy: 0.0000e+00 - val_loss: 0.3398
# Epoch 495/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1288 - val_accuracy: 0.0000e+00 - val_loss: 0.3532
# Epoch 496/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.1144 - val_accuracy: 0.0000e+00 - val_loss: 0.3357
# Epoch 497/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 0.1339 - val_accuracy: 0.0000e+00 - val_loss: 0.3554
# Epoch 498/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1293 - val_accuracy: 0.0000e+00 - val_loss: 0.3377
# Epoch 499/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1253 - val_accuracy: 0.0000e+00 - val_loss: 0.3410
# Epoch 500/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 0.1200 - val_accuracy: 0.0000e+00 - val_loss: 0.3396

# %%
fig, ax = plt.subplots(figsize=(8, 6))

ax.plot(history.history['loss'], linewidth=2, label='loss')
ax.plot(history.history['val_loss'], linewidth=2, label='val_loss')
ax.set_xlabel('Number of epochs')
ax.set_ylabel('MSE')
plt.legend()

plt.tight_layout()
plt.show()

# %%
test_predictions = model.predict(Xs_test)
train_predictions = model.predict(Xs_train)
plot_cv_vs_test(y_train, train_predictions, y_test, test_predictions, plot_titles=["Train Predictions", "Test Predictions"] )
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
