# %% [markdown]
# ## Loading data

# %%
import scipy.io

filepath = "data/1A.mat"
mat = scipy.io.loadmat(filepath)

# %%
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Wavelength', 'img'])

# %%
mat["Wavelength"]
# Out:
# array([[ 398.86],
#        [ 401.4 ],
#        [ 403.95],
#        [ 406.5 ],
#        [ 409.05],
#        [ 411.61],
#        [ 414.16],
#        [ 416.73],
#        [ 419.29],
#        [ 421.86],
#        [ 424.43],
#        [ 427.  ],
#        [ 429.57],
#        [ 432.15],
#        [ 434.73],
#        [ 437.31],
#        [ 439.9 ],
#        [ 442.49],
#        [ 445.08],
#        [ 447.67],
#        [ 450.27],
#        [ 452.86],
#        [ 455.46],
#        [ 458.07],
#        [ 460.67],
#        [ 463.28],
#        [ 465.89],
#        [ 468.5 ],
#        [ 471.12],
#        [ 473.73],
#        [ 476.35],
#        [ 478.97],
#        [ 481.59],
#        [ 484.22],
#        [ 486.84],
#        [ 489.47],
#        [ 492.1 ],
#        [ 494.74],
#        [ 497.37],
#        [ 500.01],
#        [ 502.65],
#        [ 505.29],
#        [ 507.93],
#        [ 510.58],
#        [ 513.22],
#        [ 515.87],
#        [ 518.52],
#        [ 521.17],
#        [ 523.82],
#        [ 526.48],
# ...

# %%
mat["Wavelength"].shape
# Out:
# (224, 1)

# %%
mat["img"].shape
# Out:
# (930, 1024, 224)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure()
plt.imshow(mat["img"][:,:,117])
